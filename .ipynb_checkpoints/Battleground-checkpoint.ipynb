# %%
import requests
import json
import datetime
from tqdm import tqdm
from tqdm import trange
import time
import datetime

import pandas as pd
import numpy as np

import matplotlib as mlp
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from matplotlib import patheffects

# %matplotlib inline

# %%
url = "https://api.pubg.com/tournaments"

header = {
  "Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4MGI2NmFkMC1hNGQ1LTAxM2EtYjY0Ny0wYzc0NWVlZDY1NjQiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjUwNjc4NTU0LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6Ii0zNjQxNGIzNS1iNTY1LTQ0YjUtOGIzMy01YWFkZmQ1YTIyZTYifQ.xzG8N7un8cabpwnvAAt7iTkULJSHwsveTPIf-Tap9QY",
  "Accept": "application/vnd.api+json"
}

r = requests.get(url, headers=header)
allTournamentsData = r.json()

# %%
r.text
# Out:
# '{"data":[{"type":"tournament","id":"eu-sef22","attributes":{"createdAt":"2022-10-26T15:36:54Z"}},{"type":"tournament","id":"cn-hysa22","attributes":{"createdAt":"2022-10-13T08:14:37Z"}},{"type":"tournament","id":"sea-leo30","attributes":{"createdAt":"2022-10-12T11:34:11Z"}},{"type":"tournament","id":"as-pcs7","attributes":{"createdAt":"2022-09-30T10:10:43Z"}},{"type":"tournament","id":"sea-lgs2","attributes":{"createdAt":"2022-09-28T12:12:21Z"}},{"type":"tournament","id":"cn-dyss2","attributes":{"createdAt":"2022-09-22T06:37:10Z"}},{"type":"tournament","id":"am-pcs7","attributes":{"createdAt":"2022-09-16T23:35:05Z"}},{"type":"tournament","id":"ap-pcs7","attributes":{"createdAt":"2022-09-16T11:11:45Z"}},{"type":"tournament","id":"as-apls2","attributes":{"createdAt":"2022-09-14T10:18:33Z"}},{"type":"tournament","id":"sea-leo29","attributes":{"createdAt":"2022-09-12T11:33:28Z"}},{"type":"tournament","id":"sea-plmy1","attributes":{"createdAt":"2022-09-10T04:37:49Z"}},{"type":"tournament","id":"sea-pth22","attributes":{"createdAt":"2022-09-08T09:36:34Z"}},{"type":"tournament","id":"as-lvup3","attributes":{"createdAt":"2022-09-06T10:37:02Z"}},{"type":"tournament","id":"eu-pcs7","attributes":{"createdAt":"2022-09-01T16:18:52Z"}},{"type":"tournament","id":"cn-pclpo","attributes":{"createdAt":"2022-08-31T11:41:23Z"}},{"type":"tournament","id":"sea-dpsi22","attributes":{"createdAt":"2022-08-30T12:42:58Z"}},{"type":"tournament","id":"kr-ipnc","attributes":{"createdAt":"2022-08-26T05:14:29Z"}},{"type":"tournament","id":"as-pp2gf","attributes":{"createdAt":"2022-08-25T10:25:20Z"}},{"type":"tournament","id":"kr-ipgc","attributes":{"createdAt":"2022-08-24T05:20:45Z"}},{"type":"tournament","id":"eu-esadm22","attributes":{"createdAt":"2022-08-20T16:33:58Z"}},{"type":"tournament","id":"oc-pcs7oq","attributes":{"createdAt":"2022-08-20T09:05:52Z"}},{"type":"tournament","id":"sea-pcs7oq","attributes":{"createdAt":"2022-08-19T10:09:56Z"}},{"type":"tournament","id":"na-pcs7rp","attributes":{"createdAt":"2022-08-16T23:54:13Z"}},{"type":"tournament","id":"sa-pcs7rp","attributes":{"createdAt":"2022-08-16T22:35:35Z"}},{"type":"tournament","id":"kr-goat22","attributes":{"createdAt":"2022-08-16T10:37:37Z"}},{"type":"tournament","id":"as-pp2wf4","attributes":{"createdAt":"2022-08-13T08:41:37Z"}},{"type":"tournament","id":"tw-pp2ws4","attributes":{"createdAt":"2022-08-10T10:37:52Z"}},{"type":"tournament","id":"kr-pp2ws4","attributes":{"createdAt":"2022-08-10T10:35:47Z"}},{"type":"tournament","id":"jp-pp2ws4","attributes":{"createdAt":"2022-08-10T10:27:15Z"}},{"type":"tournament","id":"eu-dachm22","attributes":{"createdAt":"2022-08-06T17:38:14Z"}},{"type":"tournament","id":"as-pp2wf3","attributes":{"createdAt":"2022-08-06T10:21:59Z"}},{"type":"tournament","id":"jp-pp2ws3","attributes":{"createdAt":"2022-08-03T10:36:10Z"}},{"type":"tournament","id":"kr-pp2ws3","attributes":{"createdAt":"2022-08-03T10:33:13Z"}},{"type":"tournament","id":"tw-pp2ws3","attributes":{"createdAt":"2022-08-03T10:30:53Z"}},{"type":"tournament","id":"sea-ptop5","attributes":{"createdAt":"2022-08-02T11:30:54Z"}},{"type":"tournament","id":"cn-pclsa22","attributes":{"createdAt":"2022-07-30T10:35:36Z"}},{"type":"tournament","id":"as-pp2wf2","attributes":{"createdAt":"2022-07-30T10:19:06Z"}},{"type":"tournament","id":"eu-gsp22","attributes":{"createdAt":"2022-07-27T15:25:18Z"}},{"type":"tournament","id":"tw-pp2ws2","attributes":{"createdAt":"2022-07-27T10:47:54Z"}},{"type":"tournament","id":"kr-pp2ws2","attributes":{"createdAt":"2022-07-27T10:28:43Z"}},{"type":"tournament","id":"jp-pp2ws2","attributes":{"createdAt":"2022-07-27T06:07:29Z"}},{"type":"tournament","id":"cn-pclsb22","attributes":{"createdAt":"2022-07-26T10:36:11Z"}},{"type":"tournament","id":"kr-ams122","attributes":{"createdAt":"2022-07-25T09:39:25Z"}},{"type":"tournament","id":"as-pp2wf1","attributes":{"createdAt":"2022-07-23T10:20:16Z"}},{"type":"tournament","id":"am-esl22p2","attributes":{"createdAt":"2022-07-22T23:20:47Z"} ...

# %%
tournamentIdlist_2021 = []
[tournamentIdlist_2021.append(targetData['id']) for targetData in allTournamentsData['data'] if (int(targetData['attributes']['createdAt'][0:4]) > 2020 and int(targetData['attributes']['createdAt'][0:4]) < 2022)]
tournamentIdlist_2021
# Out:
# ['cn-lccs2',
#  'as-pac3',
#  'as-pgcgf4',
#  'eu-dwi21',
#  'as-pgcgs4',
#  'sea-pl21',
#  'eu-eslwo',
#  'as-pgcwf3',
#  'as-ief21',
#  'eu-goat21',
#  'am-303r4',
#  'as-pgcbm2',
#  'as-pgcwf2',
#  'as-pgcbm1',
#  'eu-fls7',
#  'as-pgcwf1',
#  'as-pgcws',
#  'cn-pglas4',
#  'eu-pss3',
#  'as-pgcrd',
#  'as-dnw02',
#  'eu-pta21',
#  'eu-gma21',
#  'as-jki21',
#  'sea-aoc21',
#  'as-apl21',
#  'kr-apl21',
#  'eu-psls10',
#  'eu-cfla21',
#  'eu-eslof21',
#  'eu-pcs5w3',
#  'as-pcs5w3',
#  'am-pcs5w3',
#  'ap-pcs5w3',
#  'as-mrc2',
#  'eu-pcs5w2',
#  'as-pcs5w2',
#  'am-pcs5w2',
#  'ap-pcs5w2',
#  'eu-pcs5w1',
#  'as-pcs5w1',
#  'cn-pglas3',
#  'am-pcs5w1',
#  'eu-rbe21',
#  'ap-pcs5w1',
#  'oc-lpls3',
#  'as-kcj21',
#  'sea-cos21',
#  'cn-epcs4',
#  'as-bsc5',
#  'cn-pclpb',
#  'eu-pcs5erp',
#  'as-pws2gf',
#  'as-pws2wf5',
#  'as-pws2wc5',
#  'as-pws2ws5',
#  'na-pcs5gs',
#  'sa-pcs5gs',
#  'sea-ptop3',
#  'as-pws2wf4',
#  'eu-pcs5rp',
#  'as-pws2wc4',
#  'as-pws2ws4',
#  'as-pws2wf3',
#  'as-pws2wc3',
#  'eu-cfl21',
#  'as-pws2ws3',
#  'as-pws2wf2',
#  'sea-pcr2',
#  'am-eslm2',
#  'as-pws2wc2',
#  'as-pws2ws2',
#  'sea-ptcp6',
#  'eu_epms21',
#  'as-pws2wf1',
#  'as-pws2wc1',
#  'sea-ptsp5',
#  'as-pws2ws1',
#  'na-eslm2',
#  'sa-eslm2',
#  'cn-pclb',
#  'as-icc',
#  'sea-pvs221',
#  'eu-bpls8',
#  'eu-pros2',
#  'cn-tmc',
#  'eu-pcs4w3',
#  'as-pcs4w3',
#  'am-pcs4w3',
#  'ap-pcs4w3',
#  'eu-epo21',
#  'eu-pcs4w2',
#  'as-pcs4w2',
#  'am-pcs4w2',
#  'eu-dachc21',
#  'ap-pcs4w2',
#  'as-pcs4w1',
#  'am-pcs4w1',
#  'ap-pcs4w1',
#  'eu-pcs4w1',
#  'as-pws2tw',
#  'kr-bjms1',
#  'eu-som21',
#  'as-bsc4',
#  'eu-ens21',
#  'cn-vspn',
#  'sea-ptcp5',
#  'oc-lpls2',
#  'as-pws1gf',
#  'kr-kcc21',
#  'as-pws1wf5',
#  'as-pws1wc5',
#  'sea-ptop2',
#  'as-pws1ws5',
#  'na-pcs4gs',
#  'sa-pcs4gs',
#  'eu-psls9',
#  'as-pws1wf4',
#  'sea-pvs21',
#  'as-pws1wc4',
#  'eu-pcs4rq',
#  'as-pws1ws4',
#  'sea-vpt21',
#  'as-pws1wf3',
#  'eu-pfl21',
#  'as-pws1wc3',
#  'as-pws1ws3',
#  'sea-pcr21',
#  'as-pws1wf2',
#  'as-pws1wc2',
#  'eu-pro21',
#  'as-pws1ws2',
#  'sea-ptsp4',
#  'as-pws1wc1',
#  'as-pws1ws1',
#  'as-pws1wf1',
#  'sa-eslm1',
#  'na-eslm1',
#  'cn-pcla',
#  'am-eslm1',
#  'eu-epms21',
#  'sea-pwstw',
#  'as-aplas',
#  'sea-aplap',
#  'as-pgiwf6',
#  'oc-lpls1',
#  'as-pgiwf5',
#  'as-pgirr5',
#  'am-spark1',
#  'as-pgiwf4',
#  'as-pgirr4',
#  'eu-tps21',
#  'cn-pac',
#  'as-pgist11',
#  'as-pgist10',
#  'as-pgist09',
#  'as-pgist08',
#  'as-pgist07',
#  'as-pgist06',
#  'as-pgist05',
#  'as-pgist04',
#  'as-pgist03',
#  'as-pgist02',
#  'as-pgist01',
#  'eu-bpls7',
#  'as-pgiwf3',
#  'as-pgirr3',
#  'as-pgiwf2',
#  'as-pgirr2',
#  'eu-tpps',
#  'as-pgiwf1',
#  'as-pgirr1',
#  'eu-psls8',
#  'as-pgiws1',
#  'oc-lplps1',
#  'as-pgird',
#  'as-pjc21',
#  'as-lvup',
#  'am-303',
#  'as-pws']

# %%
print(len(tournamentIdlist_2021))
tournamentIdlist_2021 = list(set(tournamentIdlist_2021))
print(len(tournamentIdlist_2021))
# Out:
# 180
# 180

# %%
matchIdlist = []

for tournamentId in tqdm(tournamentIdlist_2021):
    url = "https://api.pubg.com/tournaments/" + tournamentId
    header = {
      "Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4MGI2NmFkMC1hNGQ1LTAxM2EtYjY0Ny0wYzc0NWVlZDY1NjQiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjUwNjc4NTU0LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6Ii0zNjQxNGIzNS1iNTY1LTQ0YjUtOGIzMy01YWFkZmQ1YTIyZTYifQ.xzG8N7un8cabpwnvAAt7iTkULJSHwsveTPIf-Tap9QY",
      "Accept": "application/vnd.api+json"
    }
    r = requests.get(url, headers=header)
    tournamentData = r.json()
    [matchIdlist.append(matchData['id']) for matchData in tournamentData['included']]
    time.sleep(7)
# Out:
#   1%|▉                                                                                 | 2/180 [00:14<21:49,  7.35s/it]

# %%
print(len(matchIdlist))
matchIdlist = list(set(matchIdlist))
print(len(matchIdlist))

# %%
textfile = open("D:\Desktop\pubgmatchid2021.txt","w")
for ids in matchIdlist:
    textfile.write(ids + "\n")
textfile.close()

# %%
matchURLList = []
for matchId in tqdm(matchIdlist):
    url = "https://api.pubg.com/shards/tournaments/matches/" + matchId
    header = {
      "Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4MGI2NmFkMC1hNGQ1LTAxM2EtYjY0Ny0wYzc0NWVlZDY1NjQiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjUwNjc4NTU0LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6Ii0zNjQxNGIzNS1iNTY1LTQ0YjUtOGIzMy01YWFkZmQ1YTIyZTYifQ.xzG8N7un8cabpwnvAAt7iTkULJSHwsveTPIf-Tap9QY",
      "Accept": "application/vnd.api+json"
    }
    r = requests.get(url, headers=header)
    matchData = r.json()
    for dat in matchData['included']:
        if dat['type'] == 'asset':
            matchURLList.append(dat['attributes']['URL'])
    time.sleep(7)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 1330/1330 [2:47:03<00:00,  7.54s/it]

# %%
print(len(matchURLList))
matchURLList = list(set(matchURLList))
print(len(matchURLList))
# Out:
# 1330
# 1330

# %%
textfile = open("D:\Desktop\pubgmatchTelemetry2022.txt","w")
for ids in matchURLList:
    textfile.write(ids + "\n")
textfile.close()

# %%
killTimeList = []

for matchURL in tqdm(matchURLList):
    header = {
      "Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4MGI2NmFkMC1hNGQ1LTAxM2EtYjY0Ny0wYzc0NWVlZDY1NjQiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjUwNjc4NTU0LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6Ii0zNjQxNGIzNS1iNTY1LTQ0YjUtOGIzMy01YWFkZmQ1YTIyZTYifQ.xzG8N7un8cabpwnvAAt7iTkULJSHwsveTPIf-Tap9QY",
      "Accept": "application/vnd.api+json"
    }
    r = requests.get(matchURL, headers=header)
    r.text
    telemetryData = r.json()
    K = []
    [K.append(x['_D']) for x in telemetryData if(x['_T'] == 'LogPlayerKillV2')]
    start = telemetryData[0]['_D']
    datetimestart = datetime.datetime.strptime(start[0:19],"%Y-%m-%dT%H:%M:%S")
    for killtime in K:
        killTimeList.append(((datetime.datetime.strptime(killtime[0:19],"%Y-%m-%dT%H:%M:%S") - datetimestart).seconds)/60)
    time.sleep(7)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 1330/1330 [3:36:14<00:00,  9.76s/it]

# %%
len(killTimeList)
# Out:
# 79512

# %%
plt.hist(killTimeList)
# Out:
# (array([ 1967.,  2848.,  4108.,  6174.,  8710., 16802., 16363., 11527.,
#          7357.,  3656.]),
#  array([ 0.2       ,  3.47166667,  6.74333333, 10.015     , 13.28666667,
#         16.55833333, 19.83      , 23.10166667, 26.37333333, 29.645     ,
#         32.91666667]),
#  <BarContainer object of 10 artists>)

# %%
tournamentIdlist_2018 = []
[tournamentIdlist_2018.append(targetData['id']) for targetData in allTournamentsData['data'] if (int(targetData['attributes']['createdAt'][0:4]) < 2019)]

matchIdlist_2018 = []

for tournamentId in tqdm(tournamentIdlist_2018):
    url = "https://api.pubg.com/tournaments/" + tournamentId
    header = {
      "Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4MGI2NmFkMC1hNGQ1LTAxM2EtYjY0Ny0wYzc0NWVlZDY1NjQiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjUwNjc4NTU0LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6Ii0zNjQxNGIzNS1iNTY1LTQ0YjUtOGIzMy01YWFkZmQ1YTIyZTYifQ.xzG8N7un8cabpwnvAAt7iTkULJSHwsveTPIf-Tap9QY",
      "Accept": "application/vnd.api+json"
    }
    r = requests.get(url, headers=header)
    tournamentData = r.json()
    [matchIdlist_2018.append(matchData['id']) for matchData in tournamentData['included']]
    time.sleep(7)

textfile = open("D:\Desktop\pubgmatchid2018.txt","w")
for ids in matchIdlist_2018:
    textfile.write(ids + "\n")
textfile.close()

print(len(matchIdlist_2018))
matchIdlist_2018 = list(set(matchIdlist_2018))
print(len(matchIdlist_2018))

matchURLList_2018 = []

for matchId in tqdm(matchIdlist_2018):
    url = "https://api.pubg.com/shards/tournaments/matches/" + matchId
    header = {
      "Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4MGI2NmFkMC1hNGQ1LTAxM2EtYjY0Ny0wYzc0NWVlZDY1NjQiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjUwNjc4NTU0LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6Ii0zNjQxNGIzNS1iNTY1LTQ0YjUtOGIzMy01YWFkZmQ1YTIyZTYifQ.xzG8N7un8cabpwnvAAt7iTkULJSHwsveTPIf-Tap9QY",
      "Accept": "application/vnd.api+json"
    }
    r = requests.get(url, headers=header)
    matchData = r.json()
    for dat in matchData['included']:
        if dat['type'] == 'asset':
            matchURLList_2018.append(dat['attributes']['URL'])
    time.sleep(7)
    
print(len(matchURLList_2018))
matchURLList_2018 = list(set(matchURLList_2018))
print(len(matchURLList_2018))

textfile = open("D:\Desktop\pubgmatchTelemetry2018.txt","w")
for ids in matchURLList_2018:
    textfile.write(ids + "\n")
textfile.close()

killTimeList_2018 = []

for matchURL in tqdm(matchURLList_2018):
    header = {
      "Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4MGI2NmFkMC1hNGQ1LTAxM2EtYjY0Ny0wYzc0NWVlZDY1NjQiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjUwNjc4NTU0LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6Ii0zNjQxNGIzNS1iNTY1LTQ0YjUtOGIzMy01YWFkZmQ1YTIyZTYifQ.xzG8N7un8cabpwnvAAt7iTkULJSHwsveTPIf-Tap9QY",
      "Accept": "application/vnd.api+json"
    }
    r = requests.get(matchURL, headers=header)
    r.text
    telemetryData = r.json()
    K = []
    [K.append(x['_D']) for x in telemetryData if(x['_T'] == 'LogPlayerKillV2')]
    start = telemetryData[0]['_D']
    datetimestart = datetime.datetime.strptime(start[0:19],"%Y-%m-%dT%H:%M:%S")
    for killtime in K:
        killTimeList_2018.append(((datetime.datetime.strptime(killtime[0:19],"%Y-%m-%dT%H:%M:%S") - datetimestart).seconds)/60)
    time.sleep(7)
    
len(killTimeList_2018)

plt.hist(killTimeList_2018)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 48/48 [05:58<00:00,  7.47s/it]
#   0%|                                                                                         | 0/2691 [00:00<?, ?it/s]
# 2691
# 2691
# 100%|████████████████████████████████████████████████████████████████████████████| 2691/2691 [5:38:04<00:00,  7.54s/it]
#   0%|                                                                                         | 0/2691 [00:00<?, ?it/s]
# 2691
# 2691
#  86%|█████████████████████████████████████████████████████████████████▌          | 2322/2691 [6:02:31<57:36,  9.37s/it]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\response.py in _decode(self, data, decode_content, flush_decoder)
#     398             if self._decoder:
# --> 399                 data = self._decoder.decompress(data)
#     400         except self.DECODER_ERROR_CLASSES as e:
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in decompress(self, data)
#      85             try:
# ---> 86                 ret += self._obj.decompress(data)
#      87             except zlib.error:
#
# error: Error -3 while decompressing data: incorrect header check
#
# During handling of the above exception, another exception occurred:
#
# DecodeError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\models.py in generate()
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     574             while not is_fp_closed(self._fp):
# --> 575                 data = self.read(amt=amt, decode_content=decode_content)
#     576
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     546
# --> 547             data = self._decode(data, decode_content, flush_decoder)
#     548
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in _decode(self, data, decode_content, flush_decoder)
#     401             content_encoding = self.headers.get("content-encoding", "").lower()
# --> 402             raise DecodeError(
#     403                 "Received response with content-encoding: %s, but "
#
# DecodeError: ('Received response with content-encoding: gzip, but failed to decode it.', error('Error -3 while decompressing data: incorrect header check'))
#
# During handling of the above exception, another exception occurred:
#
# ContentDecodingError                      Traceback (most recent call last)
# <ipython-input-76-8a9b42a94d02> in <module>
#      55       "Accept": "application/vnd.api+json"
#      56     }
# ---> 57     r = requests.get(matchURL, headers=header)
#      58     r.text
#      59     telemetryData = r.json()
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     683
#     684         if not stream:
# --> 685             r.content
#     686
#     687         return r
#
# ~\anaconda3\lib\site-packages\requests\models.py in content(self)
#     827                 self._content = None
#     828             else:
# --> 829                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     830
#     831         self._content_consumed = True
#
# ~\anaconda3\lib\site-packages\requests\models.py in generate()
#     754                     raise ChunkedEncodingError(e)
#     755                 except DecodeError as e:
# --> 756                     raise ContentDecodingError(e)
#     757                 except ReadTimeoutError as e:
#     758                     raise ConnectionError(e)
#
# ContentDecodingError: ('Received response with content-encoding: gzip, but failed to decode it.', error('Error -3 while decompressing data: incorrect header check'))

# %%
len(matchURLList_2018)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\TEAMEL~1\AppData\Local\Temp/ipykernel_2536/3937366341.py in <module>
# ----> 1 len(matchURLList_2018)
#
# NameError: name 'matchURLList_2018' is not defined

# %%
killTimeList_2018 = []

for matchURL in tqdm(matchURLList_2018):
    header = {
      "Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4MGI2NmFkMC1hNGQ1LTAxM2EtYjY0Ny0wYzc0NWVlZDY1NjQiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjUwNjc4NTU0LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6Ii0zNjQxNGIzNS1iNTY1LTQ0YjUtOGIzMy01YWFkZmQ1YTIyZTYifQ.xzG8N7un8cabpwnvAAt7iTkULJSHwsveTPIf-Tap9QY",
      "Accept": "application/vnd.api+json"
    }
    r = requests.get(matchURL, headers=header)
    r.text
    telemetryData = r.json()
    K = []
    [K.append(x['_D']) for x in telemetryData if(x['_T'] == 'LogPlayerKillV2')]
    start = telemetryData[0]['_D']
    datetimestart = datetime.datetime.strptime(start[0:19],"%Y-%m-%dT%H:%M:%S")
    for killtime in K:
        killTimeList_2018.append(((datetime.datetime.strptime(killtime[0:19],"%Y-%m-%dT%H:%M:%S") - datetimestart).seconds)/60)
    time.sleep(7)
# Out:
#  86%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                          | 2322/2691 [5:26:10<51:50,  8.43s/it]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\response.py in _decode(self, data, decode_content, flush_decoder)
#     398             if self._decoder:
# --> 399                 data = self._decoder.decompress(data)
#     400         except self.DECODER_ERROR_CLASSES as e:
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in decompress(self, data)
#      85             try:
# ---> 86                 ret += self._obj.decompress(data)
#      87             except zlib.error:
#
# error: Error -3 while decompressing data: incorrect header check
#
# During handling of the above exception, another exception occurred:
#
# DecodeError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\models.py in generate()
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     574             while not is_fp_closed(self._fp):
# --> 575                 data = self.read(amt=amt, decode_content=decode_content)
#     576
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     546
# --> 547             data = self._decode(data, decode_content, flush_decoder)
#     548
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in _decode(self, data, decode_content, flush_decoder)
#     401             content_encoding = self.headers.get("content-encoding", "").lower()
# --> 402             raise DecodeError(
#     403                 "Received response with content-encoding: %s, but "
#
# DecodeError: ('Received response with content-encoding: gzip, but failed to decode it.', error('Error -3 while decompressing data: incorrect header check'))
#
# During handling of the above exception, another exception occurred:
#
# ContentDecodingError                      Traceback (most recent call last)
# <ipython-input-79-9710579ff05d> in <module>
#       6       "Accept": "application/vnd.api+json"
#       7     }
# ----> 8     r = requests.get(matchURL, headers=header)
#       9     r.text
#      10     telemetryData = r.json()
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     683
#     684         if not stream:
# --> 685             r.content
#     686
#     687         return r
#
# ~\anaconda3\lib\site-packages\requests\models.py in content(self)
#     827                 self._content = None
#     828             else:
# --> 829                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     830
#     831         self._content_consumed = True
#
# ~\anaconda3\lib\site-packages\requests\models.py in generate()
#     754                     raise ChunkedEncodingError(e)
#     755                 except DecodeError as e:
# --> 756                     raise ContentDecodingError(e)
#     757                 except ReadTimeoutError as e:
#     758                     raise ConnectionError(e)
#
# ContentDecodingError: ('Received response with content-encoding: gzip, but failed to decode it.', error('Error -3 while decompressing data: incorrect header check'))

# %%
tournamentIdlist_2021 = []
[tournamentIdlist_2021.append(targetData['id']) for targetData in allTournamentsData['data'] if (int(targetData['attributes']['createdAt'][0:4]) < 2022 and int(targetData['attributes']['createdAt'][0:4]) > 2020)]
tournamentIdlist_2021
# Out:
# ['cn-lccs2',
#  'as-pac3',
#  'as-pgcgf4',
#  'eu-dwi21',
#  'as-pgcgs4',
#  'sea-pl21',
#  'eu-eslwo',
#  'as-pgcwf3',
#  'as-ief21',
#  'eu-goat21',
#  'am-303r4',
#  'as-pgcbm2',
#  'as-pgcwf2',
#  'as-pgcbm1',
#  'eu-fls7',
#  'as-pgcwf1',
#  'as-pgcws',
#  'cn-pglas4',
#  'eu-pss3',
#  'as-pgcrd',
#  'as-dnw02',
#  'eu-pta21',
#  'eu-gma21',
#  'as-jki21',
#  'sea-aoc21',
#  'as-apl21',
#  'kr-apl21',
#  'eu-psls10',
#  'eu-cfla21',
#  'eu-eslof21',
#  'eu-pcs5w3',
#  'as-pcs5w3',
#  'am-pcs5w3',
#  'ap-pcs5w3',
#  'as-mrc2',
#  'eu-pcs5w2',
#  'as-pcs5w2',
#  'am-pcs5w2',
#  'ap-pcs5w2',
#  'eu-pcs5w1',
#  'as-pcs5w1',
#  'cn-pglas3',
#  'am-pcs5w1',
#  'eu-rbe21',
#  'ap-pcs5w1',
#  'oc-lpls3',
#  'as-kcj21',
#  'sea-cos21',
#  'cn-epcs4',
#  'as-bsc5',
#  'cn-pclpb',
#  'eu-pcs5erp',
#  'as-pws2gf',
#  'as-pws2wf5',
#  'as-pws2wc5',
#  'as-pws2ws5',
#  'na-pcs5gs',
#  'sa-pcs5gs',
#  'sea-ptop3',
#  'as-pws2wf4',
#  'eu-pcs5rp',
#  'as-pws2wc4',
#  'as-pws2ws4',
#  'as-pws2wf3',
#  'as-pws2wc3',
#  'eu-cfl21',
#  'as-pws2ws3',
#  'as-pws2wf2',
#  'sea-pcr2',
#  'am-eslm2',
#  'as-pws2wc2',
#  'as-pws2ws2',
#  'sea-ptcp6',
#  'eu_epms21',
#  'as-pws2wf1',
#  'as-pws2wc1',
#  'sea-ptsp5',
#  'as-pws2ws1',
#  'na-eslm2',
#  'sa-eslm2',
#  'cn-pclb',
#  'as-icc',
#  'sea-pvs221',
#  'eu-bpls8',
#  'eu-pros2',
#  'cn-tmc',
#  'eu-pcs4w3',
#  'as-pcs4w3',
#  'am-pcs4w3',
#  'ap-pcs4w3',
#  'eu-epo21',
#  'eu-pcs4w2',
#  'as-pcs4w2',
#  'am-pcs4w2',
#  'eu-dachc21',
#  'ap-pcs4w2',
#  'as-pcs4w1',
#  'am-pcs4w1',
#  'ap-pcs4w1',
#  'eu-pcs4w1',
#  'as-pws2tw',
#  'kr-bjms1',
#  'eu-som21',
#  'as-bsc4',
#  'eu-ens21',
#  'cn-vspn',
#  'sea-ptcp5',
#  'oc-lpls2',
#  'as-pws1gf',
#  'kr-kcc21',
#  'as-pws1wf5',
#  'as-pws1wc5',
#  'sea-ptop2',
#  'as-pws1ws5',
#  'na-pcs4gs',
#  'sa-pcs4gs',
#  'eu-psls9',
#  'as-pws1wf4',
#  'sea-pvs21',
#  'as-pws1wc4',
#  'eu-pcs4rq',
#  'as-pws1ws4',
#  'sea-vpt21',
#  'as-pws1wf3',
#  'eu-pfl21',
#  'as-pws1wc3',
#  'as-pws1ws3',
#  'sea-pcr21',
#  'as-pws1wf2',
#  'as-pws1wc2',
#  'eu-pro21',
#  'as-pws1ws2',
#  'sea-ptsp4',
#  'as-pws1wc1',
#  'as-pws1ws1',
#  'as-pws1wf1',
#  'sa-eslm1',
#  'na-eslm1',
#  'cn-pcla',
#  'am-eslm1',
#  'eu-epms21',
#  'sea-pwstw',
#  'as-aplas',
#  'sea-aplap',
#  'as-pgiwf6',
#  'oc-lpls1',
#  'as-pgiwf5',
#  'as-pgirr5',
#  'am-spark1',
#  'as-pgiwf4',
#  'as-pgirr4',
#  'eu-tps21',
#  'cn-pac',
#  'as-pgist11',
#  'as-pgist10',
#  'as-pgist09',
#  'as-pgist08',
#  'as-pgist07',
#  'as-pgist06',
#  'as-pgist05',
#  'as-pgist04',
#  'as-pgist03',
#  'as-pgist02',
#  'as-pgist01',
#  'eu-bpls7',
#  'as-pgiwf3',
#  'as-pgirr3',
#  'as-pgiwf2',
#  'as-pgirr2',
#  'eu-tpps',
#  'as-pgiwf1',
#  'as-pgirr1',
#  'eu-psls8',
#  'as-pgiws1',
#  'oc-lplps1',
#  'as-pgird',
#  'as-pjc21',
#  'as-lvup',
#  'am-303',
#  'as-pws']

# %%
import random

# %%
tournamentIdlist_2021_samples = random.sample(tournamentIdlist_2021, k=10)

# %%
matchIdlist = []

for tournamentId in tqdm(tournamentIdlist_2021_samples):
    url = "https://api.pubg.com/tournaments/" + tournamentId
    header = {
      "Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4MGI2NmFkMC1hNGQ1LTAxM2EtYjY0Ny0wYzc0NWVlZDY1NjQiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjUwNjc4NTU0LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6Ii0zNjQxNGIzNS1iNTY1LTQ0YjUtOGIzMy01YWFkZmQ1YTIyZTYifQ.xzG8N7un8cabpwnvAAt7iTkULJSHwsveTPIf-Tap9QY",
      "Accept": "application/vnd.api+json"
    }
    r = requests.get(url, headers=header)
    tournamentData = r.json()
    [matchIdlist.append(matchData['id']) for matchData in tournamentData['included']]
    time.sleep(7)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:13<00:00,  7.38s/it]

# %%
print(len(matchIdlist))
matchIdlist = list(set(matchIdlist))
print(len(matchIdlist))
# Out:
# 510
# 510

# %%
matchURLList = []
for matchId in tqdm(matchIdlist):
    url = "https://api.pubg.com/shards/tournaments/matches/" + matchId
    header = {
      "Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4MGI2NmFkMC1hNGQ1LTAxM2EtYjY0Ny0wYzc0NWVlZDY1NjQiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjUwNjc4NTU0LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6Ii0zNjQxNGIzNS1iNTY1LTQ0YjUtOGIzMy01YWFkZmQ1YTIyZTYifQ.xzG8N7un8cabpwnvAAt7iTkULJSHwsveTPIf-Tap9QY",
      "Accept": "application/vnd.api+json"
    }
    r = requests.get(url, headers=header)
    matchData = r.json()
    for dat in matchData['included']:
        if dat['type'] == 'asset':
            matchURLList.append(dat['attributes']['URL'])
    time.sleep(7)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 510/510 [1:04:18<00:00,  7.56s/it]

# %%
killTimeList = []

for matchURL in tqdm(matchURLList):
    header = {
      "Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4MGI2NmFkMC1hNGQ1LTAxM2EtYjY0Ny0wYzc0NWVlZDY1NjQiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjUwNjc4NTU0LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6Ii0zNjQxNGIzNS1iNTY1LTQ0YjUtOGIzMy01YWFkZmQ1YTIyZTYifQ.xzG8N7un8cabpwnvAAt7iTkULJSHwsveTPIf-Tap9QY",
      "Accept": "application/vnd.api+json"
    }
    r = requests.get(matchURL, headers=header)
    r.text
    telemetryData = r.json()
    K = []
    [K.append(x['_D']) for x in telemetryData if(x['_T'] == 'LogPlayerKillV2')]
    start = telemetryData[0]['_D']
    datetimestart = datetime.datetime.strptime(start[0:19],"%Y-%m-%dT%H:%M:%S")
    for killtime in K:
        killTimeList.append(((datetime.datetime.strptime(killtime[0:19],"%Y-%m-%dT%H:%M:%S") - datetimestart).seconds)/60)
    time.sleep(7)
# Out:
#  27%|█████████████████████▎                                                          | 136/510 [21:29<59:05,  9.48s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\TEAMEL~1\AppData\Local\Temp/ipykernel_2536/4092348554.py in <module>
#      15     for killtime in K:
#      16         killTimeList.append(((datetime.datetime.strptime(killtime[0:19],"%Y-%m-%dT%H:%M:%S") - datetimestart).seconds)/60)
# ---> 17     time.sleep(7)
#
# KeyboardInterrupt:

# %%
plt.hist(killTimeList)
# Out:
# (array([ 206.,  332.,  355.,  625.,  770., 1386., 1468., 1131.,  696.,
#          504.]),
#  array([ 1.1       ,  4.26666667,  7.43333333, 10.6       , 13.76666667,
#         16.93333333, 20.1       , 23.26666667, 26.43333333, 29.6       ,
#         32.76666667]),
#  <BarContainer object of 10 artists>)

# %%
textfile = open("D:\Desktop\pubgmatchTelemetry2021sample.txt","w")
for ids in matchURLList:
    textfile.write(ids + "\n")
textfile.close()

# %%
url = "https://api.pubg.com/shards/tournaments/matches/" + matchId
header = {
  "Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4MGI2NmFkMC1hNGQ1LTAxM2EtYjY0Ny0wYzc0NWVlZDY1NjQiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjUwNjc4NTU0LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6Ii0zNjQxNGIzNS1iNTY1LTQ0YjUtOGIzMy01YWFkZmQ1YTIyZTYifQ.xzG8N7un8cabpwnvAAt7iTkULJSHwsveTPIf-Tap9QY",
  "Accept": "application/vnd.api+json"
}
r = requests.get(url, headers=header)
matchData = r.json()

# %%
matchData
# Out:
# {'data': {'type': 'match',
#   'id': '17d1f99d-d50b-49c1-b1e7-d4749cc7b089',
#   'attributes': {'duration': 1842,
#    'titleId': 'bluehole-pubg',
#    'tags': None,
#    'mapName': 'Desert_Main',
#    'matchType': '',
#    'createdAt': '2021-08-23T01:33:03Z',
#    'stats': None,
#    'gameMode': 'esports-squad-fpp',
#    'shardId': 'tournament',
#    'isCustomMatch': True,
#    'seasonState': 'progress'},
#   'relationships': {'rosters': {'data': [{'type': 'roster',
#       'id': '485c5225-8c18-48d5-aaa7-63fdf0d14180'},
#      {'type': 'roster', 'id': 'b266d765-ab26-4ee2-bd77-5d0fb7668885'},
#      {'type': 'roster', 'id': 'facc8923-ef46-4674-87f2-8d6b31309439'},
#      {'type': 'roster', 'id': '6902127e-1261-4f4a-b96a-22b3be14fadf'},
#      {'type': 'roster', 'id': '04323195-db64-4c8f-8f3c-9ef5aea74f00'},
#      {'type': 'roster', 'id': '198bc050-11d8-4644-8a60-73ecc7595923'},
#      {'type': 'roster', 'id': '42578ae8-6f30-4579-8e41-aa1d69e7d804'},
#      {'type': 'roster', 'id': '5035d74d-839b-498e-9e87-bee188242653'},
#      {'type': 'roster', 'id': '12327291-a466-4ce4-b356-cfa6983e1535'},
#      {'type': 'roster', 'id': 'db9a6950-df0c-4b3a-976b-41848ec1efb4'},
#      {'type': 'roster', 'id': '7b382d04-0eed-4eb3-86fe-ddb13beff6fe'},
#      {'type': 'roster', 'id': '35485b00-b666-42fa-992d-26cf6457e923'},
#      {'type': 'roster', 'id': 'ae1b7116-63c1-4d62-b3d8-aa2b7e6e27bb'},
#      {'type': 'roster', 'id': '2ca784bb-6f25-4468-bec4-bc06acf5dd2d'},
#      {'type': 'roster', 'id': '9521dacb-0530-4a9c-bced-662972b450ef'},
#      {'type': 'roster', 'id': '3f9c456b-44a8-4f88-bf74-e305945a4b14'}]},
#    'assets': {'data': [{'type': 'asset',
#       'id': 'a002cd73-03b6-11ec-9eb2-1e5585132444'}]}},
#   'links': {'self': 'https://api.pubg.com/shards/tournament/matches/17d1f99d-d50b-49c1-b1e7-d4749cc7b089',
#    'schema': ''}},
#  'included': [{'type': 'participant',
#    'id': '5ce547c4-689f-4f53-887f-0054cb98b7e3',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 49,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 's1_kk1te',
#      'playerId': 'account.0f7cc20c60254b8395a6ec656597c17e',
#      'revives': 0,
#      'rideDistance': 4436.13,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 682,
#      'vehicleDestroys': 0,
#      'walkDistance': 488.10965,
#      'weaponsAcquired': 5,
#      'winPlace': 11}}},
#   {'type': 'roster',
#    'id': '198bc050-11d8-4644-8a60-73ecc7595923',
#    'attributes': {'stats': {'rank': 1, 'teamId': 14},
#     'won': 'true',
#     'shardId': 'tournament'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '8d92e238-e881-4775-b300-762bacaa79e5'},
#       {'type': 'participant', 'id': '8e93fc9c-bde2-46e0-b49f-4d052cd69a2d'},
#       {'type': 'participant', 'id': '617035af-176e-4246-b005-95fbba54f669'},
#       {'type': 'participant',
#        'id': '439be968-2dc1-4ac3-babe-b6da9aad6138'}]}}},
#   {'type': 'roster',
#    'id': '3f9c456b-44a8-4f88-bf74-e305945a4b14',
#    'attributes': {'stats': {'rank': 12, 'teamId': 5},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': 'ee037bd0-22db-4466-9d84-73488cc0baa1'},
#       {'type': 'participant', 'id': 'de407ed5-9455-4fa2-a873-f2a706573049'},
#       {'type': 'participant',
#        'id': '5e23c7df-f033-4c52-b6f3-efccac3c51f9'}]}}},
#   {'type': 'participant',
#    'id': 'e405fbf7-68eb-4497-9d23-ebb07b98976c',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 5,
#      'damageDealt': 380.30276,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 3,
#      'killPlace': 13,
#      'killStreaks': 2,
#      'kills': 2,
#      'longestKill': 34.12399,
#      'name': 'VTS_Lobes',
#      'playerId': 'account.bb81785e0c0441dfa5549c8baf335d28',
#      'revives': 0,
#      'rideDistance': 3913.8135,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1352,
#      'vehicleDestroys': 0,
#      'walkDistance': 970.34064,
#      'weaponsAcquired': 8,
#      'winPlace': 7}}},
#   {'type': 'participant',
#    'id': '6071e912-ea61-489f-8fb9-4968d3dc0708',
#    'attributes': {'stats': {'DBNOs': 2,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 75.9819,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 6,
#      'killPlace': 11,
#      'killStreaks': 2,
#      'kills': 2,
#      'longestKill': 130.99432,
#      'name': 'LM_Justus',
#      'playerId': 'account.d18a2334c7f747fab49fab8526953d5e',
#      'revives': 0,
#      'rideDistance': 1649.74,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1650,
#      'vehicleDestroys': 0,
#      'walkDistance': 1675.6968,
#      'weaponsAcquired': 5,
#      'winPlace': 4},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '617035af-176e-4246-b005-95fbba54f669',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 212.03572,
#      'deathType': 'alive',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 7,
#      'killStreaks': 1,
#      'kills': 2,
#      'longestKill': 47.486664,
#      'name': 'WC_TsoK',
#      'playerId': 'account.54d4e4f16b844e5fb2a033c128aa8691',
#      'revives': 1,
#      'rideDistance': 10841.841,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1842.878,
#      'vehicleDestroys': 0,
#      'walkDistance': 505.68265,
#      'weaponsAcquired': 3,
#      'winPlace': 1},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': '6e31a9d6-d0fe-40cb-aa66-8eefd48e28f4',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 279.14908,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 4,
#      'killPlace': 32,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 166.96898,
#      'name': 'LBR_Protuhge',
#      'playerId': 'account.df9184ecdbef435fab44f23ab301b19c',
#      'revives': 0,
#      'rideDistance': 637.35175,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1153,
#      'vehicleDestroys': 0,
#      'walkDistance': 946.6398,
#      'weaponsAcquired': 3,
#      'winPlace': 13},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'a268647c-b017-4076-b9c4-a8e8cc087968',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 100,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 30,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 129.50526,
#      'name': 'WUT_Vixus',
#      'playerId': 'account.92dd205d53cd4d9489f74c1b2600726f',
#      'revives': 0,
#      'rideDistance': 3126.192,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 611,
#      'vehicleDestroys': 0,
#      'walkDistance': 646.1453,
#      'weaponsAcquired': 7,
#      'winPlace': 10}}},
#   {'type': 'participant',
#    'id': '3f924c8a-ee33-44f2-a44d-0a2fbcfa014c',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 100,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 3,
#      'killPlace': 28,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 50.986073,
#      'name': 'WUT_P4TRONTV',
#      'playerId': 'account.85d2110d848d48a2b1bcf65166013959',
#      'revives': 0,
#      'rideDistance': 3025.7346,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1324,
#      'vehicleDestroys': 0,
#      'walkDistance': 1428.7657,
#      'weaponsAcquired': 3,
#      'winPlace': 10},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '87855164-eec1-4041-94e7-84c49b03db92',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 59,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'ORN_Zaitus',
#      'playerId': 'account.53629a449aba4203a8bf72caedc86c7b',
#      'revives': 0,
#      'rideDistance': 4134.5786,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 437,
#      'vehicleDestroys': 0,
#      'walkDistance': 280.0802,
#      'weaponsAcquired': 3,
#      'winPlace': 15},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': '5e23c7df-f033-4c52-b6f3-efccac3c51f9',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 215.266,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 31,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 77.33698,
#      'name': 'GRVT_Zoveren',
#      'playerId': 'account.2a016625b8354cc68beae9edfe1867b4',
#      'revives': 0,
#      'rideDistance': 3514.64,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1151,
#      'vehicleDestroys': 0,
#      'walkDistance': 1147.9304,
#      'weaponsAcquired': 5,
#      'winPlace': 12},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '5f927208-cda6-42aa-b5ab-49ede2cca657',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 161.98839,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 3,
#      'killPlace': 20,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 234.11772,
#      'name': 'LM_Fudge',
#      'playerId': 'account.a4d836b57d8244e298e49e496193aae7',
#      'revives': 0,
#      'rideDistance': 2290.1477,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1486,
#      'vehicleDestroys': 0,
#      'walkDistance': 1641.8058,
#      'weaponsAcquired': 4,
#      'winPlace': 4},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '50cfe673-272a-4fb3-ba71-6bf1e34113a0',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 1,
#      'boosts': 5,
#      'damageDealt': 303.73447,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 4,
#      'killPlace': 44,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'SQ_hwinn',
#      'playerId': 'account.cb5ce42175e6436eb0aaa5ffde16d12f',
#      'revives': 0,
#      'rideDistance': 4432.1973,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1337,
#      'vehicleDestroys': 0,
#      'walkDistance': 1295.752,
#      'weaponsAcquired': 6,
#      'winPlace': 9},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '830dc3c1-0013-4602-b2c9-65a51db6c402',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 88.66832,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 4,
#      'killPlace': 53,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'LBR_Dash',
#      'playerId': 'account.3d9eecd31bca48e792dd1566d3ca752f',
#      'revives': 1,
#      'rideDistance': 375.323,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1167,
#      'vehicleDestroys': 1,
#      'walkDistance': 1090.9708,
#      'weaponsAcquired': 4,
#      'winPlace': 13},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '5085837d-dba6-4a2a-87e2-10d36ec84e03',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 123.465965,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 3,
#      'killPlace': 29,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 6.857465,
#      'name': 'WUT_enV',
#      'playerId': 'account.0004a4234ced43c2b7c71cc7615da505',
#      'revives': 0,
#      'rideDistance': 3144.2412,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1324,
#      'vehicleDestroys': 0,
#      'walkDistance': 875.4562,
#      'weaponsAcquired': 3,
#      'winPlace': 10},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'ba6fa30c-733a-4951-bdec-184f83eb8288',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 57,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'ORN_DirtyZinn',
#      'playerId': 'account.3468aeda2bd049a3b25a64899350614f',
#      'revives': 0,
#      'rideDistance': 6043.1343,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 799,
#      'vehicleDestroys': 0,
#      'walkDistance': 888.5285,
#      'weaponsAcquired': 4,
#      'winPlace': 15},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'ee037bd0-22db-4466-9d84-73488cc0baa1',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 135.64722,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 50,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'GRVT_Baddylul',
#      'playerId': 'account.1d756bf60f97481bbeace7f3e628eb1b',
#      'revives': 0,
#      'rideDistance': 4332.24,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1246,
#      'vehicleDestroys': 0,
#      'walkDistance': 1802.1095,
#      'weaponsAcquired': 4,
#      'winPlace': 12},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': 'db9a6950-df0c-4b3a-976b-41848ec1efb4',
#    'attributes': {'won': 'false',
#     'shardId': 'tournament',
#     'stats': {'rank': 13, 'teamId': 7}},
#    'relationships': {'participants': {'data': [{'type': 'participant',
#        'id': 'da9d8ff0-bebc-4921-a39e-83e23759d3af'},
#       {'type': 'participant', 'id': '6e31a9d6-d0fe-40cb-aa66-8eefd48e28f4'},
#       {'type': 'participant', 'id': '830dc3c1-0013-4602-b2c9-65a51db6c402'},
#       {'type': 'participant', 'id': '65b113ec-1072-48ce-bf02-92dc3bffe0b8'}]},
#     'team': {'data': None}}},
#   {'type': 'participant',
#    'id': '548acda0-7f6b-4460-ad56-914b63251705',
#    'attributes': {'stats': {'DBNOs': 3,
#      'assists': 3,
#      'boosts': 6,
#      'damageDealt': 334.91824,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 7,
#      'killPlace': 5,
#      'killStreaks': 3,
#      'kills': 3,
#      'longestKill': 33.9219,
#      'name': 'SQ_M1ME',
#      'playerId': 'account.c9bb5af911aa4bdab5bd1f9b9b653183',
#      'revives': 0,
#      'rideDistance': 5385.3394,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1337,
#      'vehicleDestroys': 0,
#      'walkDistance': 1399.0188,
#      'weaponsAcquired': 5,
#      'winPlace': 9},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '8e93fc9c-bde2-46e0-b49f-4d052cd69a2d',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 1,
#      'boosts': 12,
#      'damageDealt': 592.76666,
#      'deathType': 'alive',
#      'headshotKills': 1,
#      'heals': 9,
#      'killPlace': 8,
#      'killStreaks': 1,
#      'kills': 2,
#      'longestKill': 151.05551,
#      'name': 'WC_ZRAY',
#      'playerId': 'account.48e99d943aec4235919a8e774641d673',
#      'revives': 1,
#      'rideDistance': 10821.858,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1842.878,
#      'vehicleDestroys': 0,
#      'walkDistance': 695.4855,
#      'weaponsAcquired': 4,
#      'winPlace': 1},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'asset',
#    'id': 'a002cd73-03b6-11ec-9eb2-1e5585132444',
#    'attributes': {'name': 'telemetry',
#     'description': '',
#     'createdAt': '2021-08-23T02:05:44Z',
#     'URL': 'https://telemetry-cdn.pubg.com/bluehole-pubg/tournament/2021/08/23/02/05/a002cd73-03b6-11ec-9eb2-1e5585132444-telemetry.json'}},
#   {'type': 'participant',
#    'id': 'b1f9feae-f910-42de-9a3e-b2efe8de1792',
#    'attributes': {'stats': {'DBNOs': 2,
#      'assists': 0,
#      'boosts': 5,
#      'damageDealt': 311.32663,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 9,
#      'killStreaks': 1,
#      'kills': 2,
#      'longestKill': 134.38028,
#      'name': 'TSM_FTX_ALOW',
#      'playerId': 'account.8be6e40a75f04c93af5cd4f5f9a08a1b',
#      'revives': 0,
#      'rideDistance': 5301.6504,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1812,
#      'vehicleDestroys': 0,
#      'walkDistance': 1469.2338,
#      'weaponsAcquired': 3,
#      'winPlace': 3},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '90dc6ed8-f80c-42fc-98df-4dd00c8cfc26',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 65.142,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 37,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'LM_zukiboy',
#      'playerId': 'account.f2008c1c4d604553864a1c3ef37a6932',
#      'revives': 1,
#      'rideDistance': 3316.2498,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1650,
#      'vehicleDestroys': 0,
#      'walkDistance': 1522.2372,
#      'weaponsAcquired': 4,
#      'winPlace': 4},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '439be968-2dc1-4ac3-babe-b6da9aad6138',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 4,
#      'assists': 1,
#      'boosts': 7,
#      'damageDealt': 798.3039,
#      'deathType': 'alive',
#      'headshotKills': 1,
#      'heals': 2,
#      'killPlace': 3,
#      'killStreaks': 1,
#      'kills': 4,
#      'longestKill': 269.70157,
#      'name': 'WC_Maji',
#      'playerId': 'account.7724d6cedf304d3693654950d846c5f4',
#      'revives': 1,
#      'rideDistance': 10802.965,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1842.878,
#      'vehicleDestroys': 0,
#      'walkDistance': 611.723,
#      'weaponsAcquired': 4,
#      'winPlace': 1},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': '0d766e65-70a6-47eb-85c9-2c99b004fd81',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 1,
#      'boosts': 4,
#      'damageDealt': 245.17288,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 4,
#      'killPlace': 22,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 235.22104,
#      'name': 'DGE_Lampalot',
#      'playerId': 'account.2c8fd77505324712a82758fce624e239',
#      'revives': 1,
#      'rideDistance': 6022.1577,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1465,
#      'vehicleDestroys': 0,
#      'walkDistance': 1621.4944,
#      'weaponsAcquired': 5,
#      'winPlace': 6},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'f393e35c-0db6-4d1f-93ba-154d4a630d87',
#    'attributes': {'stats': {'DBNOs': 3,
#      'assists': 2,
#      'boosts': 3,
#      'damageDealt': 430.80933,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 10,
#      'killStreaks': 1,
#      'kills': 2,
#      'longestKill': 88.901215,
#      'name': 'TSM_FTX_luke12',
#      'playerId': 'account.58bde8fc7971420cbb3c23921efae88b',
#      'revives': 0,
#      'rideDistance': 5147.6313,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1300,
#      'vehicleDestroys': 0,
#      'walkDistance': 1512.6233,
#      'weaponsAcquired': 3,
#      'winPlace': 3},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'c99ddda0-f581-451f-a392-5f1466accc18',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 216.78413,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 43,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'VTS_Ethan',
#      'playerId': 'account.eb0476fa0dd146b6bb47330b440b531e',
#      'revives': 0,
#      'rideDistance': 1889.0671,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1165,
#      'vehicleDestroys': 0,
#      'walkDistance': 1064.2504,
#      'weaponsAcquired': 8,
#      'winPlace': 7}}},
#   {'type': 'participant',
#    'id': '8fb6b59c-4c37-4e30-8795-b7858640df09',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 3,
#      'boosts': 1,
#      'damageDealt': 488.66693,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 3,
#      'killPlace': 25,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 145.08665,
#      'name': 'eU_Corsac',
#      'playerId': 'account.a8144bc9ef7e4cfdb42c715cd1c009dc',
#      'revives': 0,
#      'rideDistance': 4716.735,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1340,
#      'vehicleDestroys': 0,
#      'walkDistance': 1217.5995,
#      'weaponsAcquired': 4,
#      'winPlace': 8},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'c8f26b73-cd24-4968-940e-d26f1a971e3a',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 56,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'KAP_Addit',
#      'playerId': 'account.4113384175634a00babfc1b6bf066d5d',
#      'revives': 0,
#      'rideDistance': 3892.8215,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 580,
#      'vehicleDestroys': 0,
#      'walkDistance': 388.99103,
#      'weaponsAcquired': 2,
#      'winPlace': 14},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '4c67db1e-9c07-4f3e-b42a-0b560600aca0',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 1,
#      'boosts': 1,
#      'damageDealt': 58.565,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 55,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'KAP_Men0xx',
#      'playerId': 'account.5a8cb49724b34881b08fd02513f3da91',
#      'revives': 0,
#      'rideDistance': 6400.009,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1048,
#      'vehicleDestroys': 0,
#      'walkDistance': 1026.1659,
#      'weaponsAcquired': 4,
#      'winPlace': 14},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': 'f8465aab-9311-421a-a26c-58e5b74b5cd6',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 146.69084,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 60,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'WP_PRINCZ',
#      'playerId': 'account.27351a248609483f803a594cae923ae7',
#      'revives': 0,
#      'rideDistance': 6510.766,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1000,
#      'vehicleDestroys': 0,
#      'walkDistance': 896.52423,
#      'weaponsAcquired': 3,
#      'winPlace': 16},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'b45eecc0-f2cf-427b-8678-5ed036ce4cf1',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 20.111172,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 61,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'WP_ArmedBurglar',
#      'playerId': 'account.0a698c129db946a2a57db73d545cb229',
#      'revives': 0,
#      'rideDistance': 5078.7246,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1000,
#      'vehicleDestroys': 0,
#      'walkDistance': 649.32166,
#      'weaponsAcquired': 6,
#      'winPlace': 16}}},
#   {'type': 'participant',
#    'id': 'fcef2d49-66fe-4d0a-9fbf-312b58df0e45',
#    'attributes': {'stats': {'DBNOs': 2,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 246.80568,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 4,
#      'killPlace': 14,
#      'killStreaks': 2,
#      'kills': 2,
#      'longestKill': 12.727475,
#      'name': 'VTS_DannyG',
#      'playerId': 'account.a2b1355a9d9f4a239bf11bcdc14e5601',
#      'revives': 0,
#      'rideDistance': 2984.8872,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1118,
#      'vehicleDestroys': 0,
#      'walkDistance': 678.22107,
#      'weaponsAcquired': 8,
#      'winPlace': 7},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'bdd4253f-6f3e-4593-877e-7b8f507e1ae9',
#    'attributes': {'stats': {'DBNOs': 2,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 243.14337,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 3,
#      'killPlace': 18,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 393.3784,
#      'name': 'OATH_Snakers',
#      'playerId': 'account.df6fd90cd6ec4570bc140f17642702d3',
#      'revives': 0,
#      'rideDistance': 1602.9187,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1736,
#      'vehicleDestroys': 0,
#      'walkDistance': 2049.223,
#      'weaponsAcquired': 6,
#      'winPlace': 2},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': 'b266d765-ab26-4ee2-bd77-5d0fb7668885',
#    'attributes': {'stats': {'rank': 8, 'teamId': 4},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '8fb6b59c-4c37-4e30-8795-b7858640df09'},
#       {'type': 'participant', 'id': '1f3e51aa-d191-4bad-a57a-b9aae01d28b4'},
#       {'type': 'participant', 'id': '726b7f65-8d0b-442d-8227-2d83186269a1'},
#       {'type': 'participant',
#        'id': '23721876-810d-47a3-9c88-8c892744c687'}]}}},
#   {'type': 'roster',
#    'id': '7b382d04-0eed-4eb3-86fe-ddb13beff6fe',
#    'attributes': {'stats': {'rank': 3, 'teamId': 13},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'participants': {'data': [{'type': 'participant',
#        'id': 'b1f9feae-f910-42de-9a3e-b2efe8de1792'},
#       {'type': 'participant', 'id': '74e41794-800d-4e0b-b4cd-a79d02b7096e'},
#       {'type': 'participant', 'id': 'f393e35c-0db6-4d1f-93ba-154d4a630d87'},
#       {'type': 'participant', 'id': 'b0a1081a-0a4a-4638-91ee-9763afb298b4'}]},
#     'team': {'data': None}}},
#   {'type': 'participant',
#    'id': '3d6c09db-d339-44cd-af22-afad1dc3ea5a',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 1,
#      'boosts': 2,
#      'damageDealt': 86.22518,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 13,
#      'killPlace': 39,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'ETR_Vexyl',
#      'playerId': 'account.233519da44434fba8232efbeadde7f97',
#      'revives': 0,
#      'rideDistance': 7126.841,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1497,
#      'vehicleDestroys': 0,
#      'walkDistance': 1664.7942,
#      'weaponsAcquired': 3,
#      'winPlace': 5},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': 'b91cb664-52ab-4ad1-bf2c-cc942f82eb95',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 62,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'WP_Baccmonster',
#      'playerId': 'account.d668ba97a4224fdeadb0270909241980',
#      'revives': 0,
#      'rideDistance': 4764.0083,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1000,
#      'vehicleDestroys': 0,
#      'walkDistance': 716.3334,
#      'weaponsAcquired': 3,
#      'winPlace': 16},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '2897481d-1990-4574-a394-18e43f7eeaa7',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 51.762764,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 41,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'DGE_HalloSenpai',
#      'playerId': 'account.b2513137b40947f291db690edc3b3d7a',
#      'revives': 0,
#      'rideDistance': 5522.3237,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1102,
#      'vehicleDestroys': 0,
#      'walkDistance': 961.8615,
#      'weaponsAcquired': 3,
#      'winPlace': 6},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': '12327291-a466-4ce4-b356-cfa6983e1535',
#    'attributes': {'stats': {'rank': 6, 'teamId': 1},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '0d766e65-70a6-47eb-85c9-2c99b004fd81'},
#       {'type': 'participant', 'id': 'a67be188-d182-496f-aafe-d0117247e70f'},
#       {'type': 'participant', 'id': 'e4d8f81e-6a1d-44b1-a8b4-641dc33f15fa'},
#       {'type': 'participant',
#        'id': '2897481d-1990-4574-a394-18e43f7eeaa7'}]}}},
#   {'type': 'participant',
#    'id': '1f3e51aa-d191-4bad-a57a-b9aae01d28b4',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 186.7284,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 26,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 104.997894,
#      'name': 'eU_Waldoe',
#      'playerId': 'account.3db0dd9834e84fd3ad79f51a6f05c974',
#      'revives': 0,
#      'rideDistance': 5620.52,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1340,
#      'vehicleDestroys': 0,
#      'walkDistance': 1174.7635,
#      'weaponsAcquired': 3,
#      'winPlace': 8},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '579d381d-473f-433a-b953-3071ca2fefaa',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 47.821587,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 6,
#      'killPlace': 40,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'ETR_Maurnzz',
#      'playerId': 'account.b89f12e0e9af4915a4ebe88688906f70',
#      'revives': 0,
#      'rideDistance': 7632.266,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1430,
#      'vehicleDestroys': 0,
#      'walkDistance': 1454.8348,
#      'weaponsAcquired': 6,
#      'winPlace': 5},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '20896f92-a654-4320-ad4c-b19c8bf1b55a',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 2,
#      'assists': 1,
#      'boosts': 7,
#      'damageDealt': 224.20792,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 6,
#      'killPlace': 12,
#      'killStreaks': 1,
#      'kills': 2,
#      'longestKill': 127.57321,
#      'name': 'ETR_Joombie',
#      'playerId': 'account.e14a89db652e4c07b4ba81b1eb90b45d',
#      'revives': 4,
#      'rideDistance': 6429.938,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1497,
#      'vehicleDestroys': 0,
#      'walkDistance': 1789.3428,
#      'weaponsAcquired': 5,
#      'winPlace': 5},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': 'da9d8ff0-bebc-4921-a39e-83e23759d3af',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 97.68,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 54,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'LBR_IceTech',
#      'playerId': 'account.20636018097841ec9afdf38a28afa0b0',
#      'revives': 0,
#      'rideDistance': 146.48238,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 241,
#      'vehicleDestroys': 0,
#      'walkDistance': 413.46628,
#      'weaponsAcquired': 3,
#      'winPlace': 13},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '34696f71-1bef-4672-82c8-a2a281a3420a',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 63,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'WP_Ghosst',
#      'playerId': 'account.c99f24a73bc74c868e72ec1516b207a1',
#      'revives': 0,
#      'rideDistance': 3938.6113,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 859,
#      'vehicleDestroys': 0,
#      'walkDistance': 967.5762,
#      'weaponsAcquired': 4,
#      'winPlace': 16},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': '42578ae8-6f30-4579-8e41-aa1d69e7d804',
#    'attributes': {'stats': {'rank': 11, 'teamId': 2},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '0dff5a26-300c-46ef-9951-bcb48da7d711'},
#       {'type': 'participant', 'id': '5ce547c4-689f-4f53-887f-0054cb98b7e3'},
#       {'type': 'participant', 'id': '04cd1d1f-4919-4372-bd64-1dc70478f601'},
#       {'type': 'participant',
#        'id': '996ca0d3-2314-44b6-b108-d1a07ec30470'}]}}},
#   {'type': 'roster',
#    'id': '35485b00-b666-42fa-992d-26cf6457e923',
#    'attributes': {'stats': {'rank': 14, 'teamId': 8},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': 'f3d278df-6545-47ab-b170-bf5dbbc41523'},
#       {'type': 'participant', 'id': 'f324c5f4-cf17-42c5-9775-d922e3e6d158'},
#       {'type': 'participant', 'id': 'c8f26b73-cd24-4968-940e-d26f1a971e3a'},
#       {'type': 'participant',
#        'id': '4c67db1e-9c07-4f3e-b42a-0b560600aca0'}]}}},
#   {'type': 'participant',
#    'id': '857dd4a3-5df6-4297-84d3-9642309cb091',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 2,
#      'boosts': 5,
#      'damageDealt': 448.35202,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 5,
#      'killPlace': 38,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'LM_Dreamzz',
#      'playerId': 'account.ffef6260e115401c84eedea1b2b2cef2',
#      'revives': 0,
#      'rideDistance': 3455.046,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1650,
#      'vehicleDestroys': 0,
#      'walkDistance': 1582.2437,
#      'weaponsAcquired': 5,
#      'winPlace': 4},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '2d59e430-087c-42cc-a04b-69e003f4dc15',
#    'attributes': {'stats': {'DBNOs': 4,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 736.42004,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 7,
#      'killPlace': 4,
#      'killStreaks': 2,
#      'kills': 3,
#      'longestKill': 77.34698,
#      'name': 'OATH_Kickstart',
#      'playerId': 'account.0b2f3e61d3d544b29fc713de8ac3e3db',
#      'revives': 1,
#      'rideDistance': 2655.4365,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1842,
#      'vehicleDestroys': 0,
#      'walkDistance': 1577.8204,
#      'weaponsAcquired': 10,
#      'winPlace': 2},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '26635f5a-9951-40b2-a9ca-63ea2109af62',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 239.52905,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 4,
#      'killPlace': 17,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 371.51254,
#      'name': 'OATH_Balefrost',
#      'playerId': 'account.533a7efc666d42c7a4b4d3fd8c2d5e3f',
#      'revives': 0,
#      'rideDistance': 1444.0999,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1741,
#      'vehicleDestroys': 0,
#      'walkDistance': 1381.2852,
#      'weaponsAcquired': 23,
#      'winPlace': 2},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '8d92e238-e881-4775-b300-762bacaa79e5',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 35,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'WC_Zealot',
#      'playerId': 'account.2316140fdfb3402ba2afbe2b75d90579',
#      'revives': 0,
#      'rideDistance': 9361.479,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 807,
#      'vehicleDestroys': 0,
#      'walkDistance': 581.865,
#      'weaponsAcquired': 4,
#      'winPlace': 1},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': '74e41794-800d-4e0b-b4cd-a79d02b7096e',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 5,
#      'damageDealt': 205.52864,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 3,
#      'killPlace': 19,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 152.55449,
#      'name': 'TSM_FTX_penta',
#      'playerId': 'account.8560681f352d45baad15f1451444cf92',
#      'revives': 0,
#      'rideDistance': 3447.433,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1812,
#      'vehicleDestroys': 0,
#      'walkDistance': 1844.1746,
#      'weaponsAcquired': 4,
#      'winPlace': 3},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '5cade086-e8dc-4772-a32b-8018b86aae9c',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 250.23969,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 2,
#      'killPlace': 45,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'WUT_Blissey',
#      'playerId': 'account.fbfb91e1b14149aabadbd7e3806596a7',
#      'revives': 0,
#      'rideDistance': 3007.026,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1290,
#      'vehicleDestroys': 0,
#      'walkDistance': 986.2247,
#      'weaponsAcquired': 5,
#      'winPlace': 10},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '0e503cfb-d46b-4eb0-ac35-f09d82e77489',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 6,
#      'damageDealt': 99.942085,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 2,
#      'killPlace': 34,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 6.5497713,
#      'name': 'ORN_Sociopath',
#      'playerId': 'account.93f82da87b1940caba5810150d69bde9',
#      'revives': 0,
#      'rideDistance': 6414.4033,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1065,
#      'vehicleDestroys': 0,
#      'walkDistance': 1208.5913,
#      'weaponsAcquired': 4,
#      'winPlace': 15},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': 'facc8923-ef46-4674-87f2-8d6b31309439',
#    'attributes': {'stats': {'rank': 4, 'teamId': 6},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '857dd4a3-5df6-4297-84d3-9642309cb091'},
#       {'type': 'participant', 'id': '5f927208-cda6-42aa-b5ab-49ede2cca657'},
#       {'type': 'participant', 'id': '90dc6ed8-f80c-42fc-98df-4dd00c8cfc26'},
#       {'type': 'participant',
#        'id': '6071e912-ea61-489f-8fb9-4968d3dc0708'}]}}},
#   {'type': 'participant',
#    'id': '726b7f65-8d0b-442d-8227-2d83186269a1',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 4,
#      'assists': 1,
#      'boosts': 2,
#      'damageDealt': 426.22137,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 1,
#      'killStreaks': 3,
#      'kills': 5,
#      'longestKill': 138.12445,
#      'name': 'eU_Valliate',
#      'playerId': 'account.8aa383fd88ce4c94953549221d30e088',
#      'revives': 0,
#      'rideDistance': 5107.449,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1340,
#      'vehicleDestroys': 0,
#      'walkDistance': 1388.935,
#      'weaponsAcquired': 3,
#      'winPlace': 8}}},
#   {'type': 'participant',
#    'id': '5cc442dd-6fce-45ab-9a38-c62a0ea536ef',
#    'attributes': {'stats': {'DBNOs': 2,
#      'assists': 0,
#      'boosts': 8,
#      'damageDealt': 557.997,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 11,
#      'killPlace': 16,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 27.648201,
#      'name': 'OATH_Relo',
#      'playerId': 'account.0438f2c8dff5418d9b23ad28f861a851',
#      'revives': 0,
#      'rideDistance': 3462.3003,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1842,
#      'vehicleDestroys': 0,
#      'walkDistance': 1524.4198,
#      'weaponsAcquired': 3,
#      'winPlace': 2},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': 'ae1b7116-63c1-4d62-b3d8-aa2b7e6e27bb',
#    'attributes': {'stats': {'rank': 16, 'teamId': 15},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '34696f71-1bef-4672-82c8-a2a281a3420a'},
#       {'type': 'participant', 'id': 'f8465aab-9311-421a-a26c-58e5b74b5cd6'},
#       {'type': 'participant', 'id': 'b45eecc0-f2cf-427b-8678-5ed036ce4cf1'},
#       {'type': 'participant',
#        'id': 'b91cb664-52ab-4ad1-bf2c-cc942f82eb95'}]}}},
#   {'type': 'participant',
#    'id': '927c0544-61a7-482e-87ba-9fd274e89118',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 1,
#      'boosts': 5,
#      'damageDealt': 245.53206,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 3,
#      'killPlace': 21,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 96.80761,
#      'name': 'ETR_SneakAttack',
#      'playerId': 'account.1298c53210cd476ab0cc9132355473b8',
#      'revives': 0,
#      'rideDistance': 6308.6313,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1497,
#      'vehicleDestroys': 0,
#      'walkDistance': 1623.0865,
#      'weaponsAcquired': 5,
#      'winPlace': 5},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'e4d8f81e-6a1d-44b1-a8b4-641dc33f15fa',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 1,
#      'boosts': 6,
#      'damageDealt': 273.72116,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 5,
#      'killPlace': 23,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 13.76372,
#      'name': 'DGE_Vegas',
#      'playerId': 'account.d8ee0670483244459380c820fd4a9a80',
#      'revives': 1,
#      'rideDistance': 7192.658,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1460,
#      'vehicleDestroys': 0,
#      'walkDistance': 1245.2666,
#      'weaponsAcquired': 6,
#      'winPlace': 6},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': '04323195-db64-4c8f-8f3c-9ef5aea74f00',
#    'attributes': {'stats': {'rank': 9, 'teamId': 11},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '50cfe673-272a-4fb3-ba71-6bf1e34113a0'},
#       {'type': 'participant', 'id': '793294ad-816d-4528-9f98-4b45cbcc19f3'},
#       {'type': 'participant', 'id': '544d7fd3-91b1-4584-b6f4-6e1f3cbb56e2'},
#       {'type': 'participant',
#        'id': '548acda0-7f6b-4460-ad56-914b63251705'}]}}},
#   {'type': 'roster',
#    'id': '9521dacb-0530-4a9c-bced-662972b450ef',
#    'attributes': {'stats': {'rank': 15, 'teamId': 10},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '64cc5a20-3d90-4377-bfe9-a5687c01626a'},
#       {'type': 'participant', 'id': 'ba6fa30c-733a-4951-bdec-184f83eb8288'},
#       {'type': 'participant', 'id': '0e503cfb-d46b-4eb0-ac35-f09d82e77489'},
#       {'type': 'participant',
#        'id': '87855164-eec1-4041-94e7-84c49b03db92'}]}}},
#   {'type': 'participant',
#    'id': '793294ad-816d-4528-9f98-4b45cbcc19f3',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 1,
#      'assists': 2,
#      'boosts': 8,
#      'damageDealt': 399.52853,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 15,
#      'killStreaks': 1,
#      'kills': 2,
#      'longestKill': 23.537674,
#      'name': 'SQ_TGLTN',
#      'playerId': 'account.d7fa105a966e4264bb52c41e177b0a8b',
#      'revives': 0,
#      'rideDistance': 5150.089,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1337,
#      'vehicleDestroys': 0,
#      'walkDistance': 1138.0802,
#      'weaponsAcquired': 5,
#      'winPlace': 9},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': '996ca0d3-2314-44b6-b108-d1a07ec30470',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 48,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 's1_Fizzle',
#      'playerId': 'account.0a55e6a9800e4f0c8b603cd180d52954',
#      'revives': 0,
#      'rideDistance': 3419.7935,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 743,
#      'vehicleDestroys': 0,
#      'walkDistance': 1038.4711,
#      'weaponsAcquired': 3,
#      'winPlace': 11},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'f324c5f4-cf17-42c5-9775-d922e3e6d158',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 5,
#      'damageDealt': 133.46568,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 4,
#      'killPlace': 33,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 18.975018,
#      'name': 'KAP_Super',
#      'playerId': 'account.766e3b64317a4af288ba4acbcf4cfd3c',
#      'revives': 0,
#      'rideDistance': 5565.2104,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1157,
#      'vehicleDestroys': 0,
#      'walkDistance': 1263.2505,
#      'weaponsAcquired': 5,
#      'winPlace': 14}}},
#   {'type': 'roster',
#    'id': '5035d74d-839b-498e-9e87-bee188242653',
#    'attributes': {'stats': {'rank': 5, 'teamId': 3},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '20896f92-a654-4320-ad4c-b19c8bf1b55a'},
#       {'type': 'participant', 'id': '579d381d-473f-433a-b953-3071ca2fefaa'},
#       {'type': 'participant', 'id': '3d6c09db-d339-44cd-af22-afad1dc3ea5a'},
#       {'type': 'participant',
#        'id': '927c0544-61a7-482e-87ba-9fd274e89118'}]}}},
#   {'type': 'participant',
#    'id': '63433395-756f-4b71-b3fe-99d065043a81',
#    'attributes': {'stats': {'DBNOs': 2,
#      'assists': 1,
#      'boosts': 4,
#      'damageDealt': 401.76306,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 24,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 22.894464,
#      'name': 'VTS_JRhead',
#      'playerId': 'account.81566ae0a56a427c8f764c10c0a316a8',
#      'revives': 0,
#      'rideDistance': 1711.2937,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1302,
#      'vehicleDestroys': 0,
#      'walkDistance': 1123.4054,
#      'weaponsAcquired': 6,
#      'winPlace': 7},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '04cd1d1f-4919-4372-bd64-1dc70478f601',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 2,
#      'assists': 0,
#      'boosts': 6,
#      'damageDealt': 151.84222,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 6,
#      'killPlace': 46,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 's1_Hoshi',
#      'playerId': 'account.b4751dfe7bfb452db0f407aed6a17196',
#      'revives': 0,
#      'rideDistance': 2772.1533,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1252,
#      'vehicleDestroys': 0,
#      'walkDistance': 1862.6172,
#      'weaponsAcquired': 4,
#      'winPlace': 11}}},
#   {'type': 'participant',
#    'id': 'a67be188-d182-496f-aafe-d0117247e70f',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 2,
#      'killPlace': 42,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'DGE_f1nna',
#      'playerId': 'account.9a11678e24ae4ef8a22234d098fdde48',
#      'revives': 0,
#      'rideDistance': 5301.8677,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1088,
#      'vehicleDestroys': 0,
#      'walkDistance': 1532.8335,
#      'weaponsAcquired': 6,
#      'winPlace': 6}}},
#   {'type': 'participant',
#    'id': '65b113ec-1072-48ce-bf02-92dc3bffe0b8',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 99.48235,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 3,
#      'killPlace': 52,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'LBR_JSON',
#      'playerId': 'account.3c1e6f14723e4cc296b5f3126d228422',
#      'revives': 0,
#      'rideDistance': 1459.0402,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1180,
#      'vehicleDestroys': 0,
#      'walkDistance': 1397.7454,
#      'weaponsAcquired': 3,
#      'winPlace': 13},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'b0a1081a-0a4a-4638-91ee-9763afb298b4',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 1,
#      'boosts': 7,
#      'damageDealt': 102.12044,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 36,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'TSM_FTX_Purdy',
#      'playerId': 'account.5d771470af29410b9357baa03b76ae15',
#      'revives': 0,
#      'rideDistance': 5313.4614,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1241,
#      'vehicleDestroys': 0,
#      'walkDistance': 1397.3739,
#      'weaponsAcquired': 6,
#      'winPlace': 3},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '23721876-810d-47a3-9c88-8c892744c687',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 1,
#      'boosts': 3,
#      'damageDealt': 121.298874,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 2,
#      'killPlace': 27,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 57.676884,
#      'name': 'eU_LosHD',
#      'playerId': 'account.2960082305b54101b1a9cf81d4993e93',
#      'revives': 0,
#      'rideDistance': 4602.586,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1340,
#      'vehicleDestroys': 0,
#      'walkDistance': 1538.0945,
#      'weaponsAcquired': 5,
#      'winPlace': 8},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '544d7fd3-91b1-4584-b6f4-6e1f3cbb56e2',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 3,
#      'assists': 1,
#      'boosts': 8,
#      'damageDealt': 627.8204,
#      'deathType': 'byplayer',
#      'headshotKills': 2,
#      'heals': 5,
#      'killPlace': 2,
#      'killStreaks': 2,
#      'kills': 5,
#      'longestKill': 83.981995,
#      'name': 'SQ_Shrimzy',
#      'playerId': 'account.dfce11166d1040bbabd8088d42e2bfff',
#      'revives': 1,
#      'rideDistance': 4512.1807,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1337,
#      'vehicleDestroys': 1,
#      'walkDistance': 1422.7427,
#      'weaponsAcquired': 7,
#      'winPlace': 9},
#     'actor': ''}},
#   {'type': 'roster',
#    'id': '6902127e-1261-4f4a-b96a-22b3be14fadf',
#    'attributes': {'stats': {'rank': 2, 'teamId': 9},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': 'bdd4253f-6f3e-4593-877e-7b8f507e1ae9'},
#       {'type': 'participant', 'id': '5cc442dd-6fce-45ab-9a38-c62a0ea536ef'},
#       {'type': 'participant', 'id': '2d59e430-087c-42cc-a04b-69e003f4dc15'},
#       {'type': 'participant',
#        'id': '26635f5a-9951-40b2-a9ca-63ea2109af62'}]}}},
#   {'type': 'participant',
#    'id': '64cc5a20-3d90-4377-bfe9-a5687c01626a',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 58,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'ORN_Skazka',
#      'playerId': 'account.b01225e87146477a8758fe83fc42a49e',
#      'revives': 0,
#      'rideDistance': 4968.7974,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 474,
#      'vehicleDestroys': 1,
#      'walkDistance': 435.82895,
#      'weaponsAcquired': 4,
#      'winPlace': 15},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': 'de407ed5-9455-4fa2-a873-f2a706573049',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 51,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'GRVT_icoNDks',
#      'playerId': 'account.cfebac1d4de342b494d88f118216c213',
#      'revives': 0,
#      'rideDistance': 1445.7242,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 311,
#      'vehicleDestroys': 0,
#      'walkDistance': 292.12366,
#      'weaponsAcquired': 5,
#      'winPlace': 12},
#     'actor': ''}},
#   {'type': 'roster',
#    'id': '485c5225-8c18-48d5-aaa7-63fdf0d14180',
#    'attributes': {'stats': {'rank': 7, 'teamId': 12},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '63433395-756f-4b71-b3fe-99d065043a81'},
#       {'type': 'participant', 'id': 'c99ddda0-f581-451f-a392-5f1466accc18'},
#       {'type': 'participant', 'id': 'e405fbf7-68eb-4497-9d23-ebb07b98976c'},
#       {'type': 'participant',
#        'id': 'fcef2d49-66fe-4d0a-9fbf-312b58df0e45'}]}}},
#   {'type': 'roster',
#    'id': '2ca784bb-6f25-4468-bec4-bc06acf5dd2d',
#    'attributes': {'stats': {'rank': 10, 'teamId': 16},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'participants': {'data': [{'type': 'participant',
#        'id': '5cade086-e8dc-4772-a32b-8018b86aae9c'},
#       {'type': 'participant', 'id': '5085837d-dba6-4a2a-87e2-10d36ec84e03'},
#       {'type': 'participant', 'id': 'a268647c-b017-4076-b9c4-a8e8cc087968'},
#       {'type': 'participant', 'id': '3f924c8a-ee33-44f2-a44d-0a2fbcfa014c'}]},
#     'team': {'data': None}}},
#   {'type': 'participant',
#    'id': '0dff5a26-300c-46ef-9951-bcb48da7d711',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 48.660606,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 47,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 's1_JayAllDay',
#      'playerId': 'account.7639544724464af988250f6cf03d7653',
#      'revives': 0,
#      'rideDistance': 2315.7485,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 855,
#      'vehicleDestroys': 0,
#      'walkDistance': 697.24005,
#      'weaponsAcquired': 8,
#      'winPlace': 11}}},
#   {'type': 'participant',
#    'id': 'f3d278df-6545-47ab-b170-bf5dbbc41523',
#    'attributes': {'stats': {'DBNOs': 2,
#      'assists': 1,
#      'boosts': 0,
#      'damageDealt': 273.53186,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 6,
#      'killStreaks': 3,
#      'kills': 3,
#      'longestKill': 46.35646,
#      'name': 'KAP_Monte',
#      'playerId': 'account.e708ec751bbf4ff38aea6a58a3f21675',
#      'revives': 0,
#      'rideDistance': 5082.8335,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1010,
#      'vehicleDestroys': 0,
#      'walkDistance': 1177.9762,
#      'weaponsAcquired': 5,
#      'winPlace': 14},
#     'actor': '',
#     'shardId': 'steam'}}],
#  'links': {'self': 'https://api-origin.playbattlegrounds.com/shards/tournaments/matches/17d1f99d-d50b-49c1-b1e7-d4749cc7b089'},
#  'meta': {}}

# %%
tournamentIdlist_2022 = []
[tournamentIdlist_2022.append(targetData['id']) for targetData in allTournamentsData['data'] if (int(targetData['attributes']['createdAt'][0:4]) > 2021)]
tournamentIdlist_2022
# Out:
# ['eu-pcs6',
#  'as-pcs6',
#  'eu-tgs22',
#  'eu-trt22',
#  'eu-goats22',
#  'as-apls1',
#  'eu-esapa',
#  'am-pcs6',
#  'ap-pcs6',
#  'as-lvup2',
#  'eu-pcs6wrp',
#  'eu-pcs6mrp',
#  'as-pp1gf',
#  'eu-pslss22',
#  'as-pp1wf4',
#  'tw-pp1ws4',
#  'kr-pp1ws4',
#  'jp-pp1ws4',
#  'oc-pcs6oq',
#  'eu-gls5',
#  'as-pp1wf3',
#  'sea-pcr22',
#  'sea-ptop4',
#  'tw-pp1ws3',
#  'jp-pp1ws3',
#  'kr-pp1ws3',
#  'na-pcs6rp',
#  'sa-pcs6rp',
#  'as-pp1em2',
#  'cn-pcls22',
#  'as-pp1em1',
#  'sea-pvs22',
#  'as-pp1wf2',
#  'eu-gm22',
#  'tw-pp1ws2',
#  'kr-pp1ws2',
#  'jp-pp1ws2',
#  'cn-pclc',
#  'as-pp1wf1',
#  'am-esl22p1',
#  'tw-pp1ws1',
#  'kr-pp1ws1',
#  'jp-pp1ws1',
#  'eu-pls4',
#  'sea-pvo22',
#  'as-pubg',
#  'na-esl22p1',
#  'sa-esl22p1',
#  'sea-ptsp6',
#  'sea-ptcp7',
#  'as-bsc6',
#  'as-pwsjp22',
#  'as-pwstw22',
#  'cn-bpcs2']

# %%
import random

tournamentIdlist_2022 = random.sample(tournamentIdlist_2022, k=3)

matchIdlist = []


for tournamentId in tqdm(tournamentIdlist_2022):
    url = "https://api.pubg.com/tournaments/" + tournamentId
    header = {
      "Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4MGI2NmFkMC1hNGQ1LTAxM2EtYjY0Ny0wYzc0NWVlZDY1NjQiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjUwNjc4NTU0LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6Ii0zNjQxNGIzNS1iNTY1LTQ0YjUtOGIzMy01YWFkZmQ1YTIyZTYifQ.xzG8N7un8cabpwnvAAt7iTkULJSHwsveTPIf-Tap9QY",
      "Accept": "application/vnd.api+json"
    }
    r = requests.get(url, headers=header)
    tournamentData = r.json()
    [matchIdlist.append(matchData['id']) for matchData in tournamentData['included']]
    time.sleep(7)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:21<00:00,  7.26s/it]

# %%
matchURLList = []
for matchId in tqdm(matchIdlist):
    url = "https://api.pubg.com/shards/tournaments/matches/" + matchId
    header = {
      "Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4MGI2NmFkMC1hNGQ1LTAxM2EtYjY0Ny0wYzc0NWVlZDY1NjQiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjUwNjc4NTU0LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6Ii0zNjQxNGIzNS1iNTY1LTQ0YjUtOGIzMy01YWFkZmQ1YTIyZTYifQ.xzG8N7un8cabpwnvAAt7iTkULJSHwsveTPIf-Tap9QY",
      "Accept": "application/vnd.api+json"
    }
    r = requests.get(url, headers=header)
    matchData = r.json()
    for dat in matchData['included']:
        if dat['type'] == 'asset':
            matchURLList.append(dat['attributes']['URL'])
    time.sleep(7)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [05:17<00:00,  7.56s/it]

# %%
header = {
      "Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4MGI2NmFkMC1hNGQ1LTAxM2EtYjY0Ny0wYzc0NWVlZDY1NjQiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjUwNjc4NTU0LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6Ii0zNjQxNGIzNS1iNTY1LTQ0YjUtOGIzMy01YWFkZmQ1YTIyZTYifQ.xzG8N7un8cabpwnvAAt7iTkULJSHwsveTPIf-Tap9QY",
      "Accept": "application/vnd.api+json"
    }
r = requests.get(matchURLList[0], headers=header)
r.text
telemetryData = r.json()

# %%
telemetryData
# Out:
# [{'MatchId': 'match.bro.custom.es_tw-pp1ws4_01.steam.normal.krjp.2022.03.24.11.08c37e03-8701-456c-be0f-f415222bfec7',
#   'PingQuality': '',
#   '_D': '2022-03-24T11:21:58.3852715Z',
#   '_T': 'LogMatchDefinition'},
#  {'accountId': 'account.0572d9280f7d435fb6db1d992ff5f8d6',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:22.911Z',
#   '_T': 'LogPlayerLogin'},
#  {'accountId': 'account.c84c69d1a2e5440482ddeda4c6158efe',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:22.917Z',
#   '_T': 'LogPlayerLogin'},
#  {'accountId': 'account.a5357a4b2c0f46228cb601fc11e2a9c2',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.025Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'KSR_P0rr1dge',
#    'teamId': 12,
#    'health': 100,
#    'location': {'x': 587027, 'y': 334203.78125, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.a5357a4b2c0f46228cb601fc11e2a9c2',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.048Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.a019bcd905ca428c9472fef49c63269d',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.049Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'DEST_ChunQ1ng',
#    'teamId': 8,
#    'health': 100,
#    'location': {'x': 790805.25, 'y': 341487.375, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.a019bcd905ca428c9472fef49c63269d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.068Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.e95604a805244c69a330bfaea6182ede',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.069Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'KSR_LzHan',
#    'teamId': 12,
#    'health': 100,
#    'location': {'x': 586687.1875, 'y': 334314.59375, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.e95604a805244c69a330bfaea6182ede',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.089Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.2fecaa3db221434faf2ff427c075b47b',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.091Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'AE_MaoRush',
#    'teamId': 1,
#    'health': 100,
#    'location': {'x': 790420.25, 'y': 341499.84375, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.2fecaa3db221434faf2ff427c075b47b',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.107Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.2dc85ea2f3e6423f9b2fcdedd0843557',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.195Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'ACN_OkYouDiE',
#    'teamId': 3,
#    'health': 100,
#    'location': {'x': 587121.6875, 'y': 333905.875, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.2dc85ea2f3e6423f9b2fcdedd0843557',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.207Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.aa5076cf4b6e41f0b3047539eca098dc',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.208Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'RKA_YouZeMoLe',
#    'teamId': 13,
#    'health': 100,
#    'location': {'x': 82548.6796875, 'y': 732568.625, 'z': 5167.130859375},
#    'ranking': 0,
#    'accountId': 'account.aa5076cf4b6e41f0b3047539eca098dc',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.220Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.96568b60ee4c4f16b93303cd1868e1ec',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.241Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'DEST_C8Jason',
#    'teamId': 8,
#    'health': 100,
#    'location': {'x': 790437.1875, 'y': 340369.5, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.96568b60ee4c4f16b93303cd1868e1ec',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.253Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.2af5557929de48afa7fe370996b0cbe5',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.254Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'ACT_MaoMao',
#    'teamId': 4,
#    'health': 100,
#    'location': {'x': 83233.703125, 'y': 730207.875, 'z': 5137.68359375},
#    'ranking': 0,
#    'accountId': 'account.2af5557929de48afa7fe370996b0cbe5',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.265Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.27b7ad383e454c80becf03dcd5b0fe7c',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.288Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'AOC_oeL',
#    'teamId': 5,
#    'health': 100,
#    'location': {'x': 587846.875, 'y': 332895.125, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.27b7ad383e454c80becf03dcd5b0fe7c',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.299Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.28991bc80143444fbc3fe4d53988c0f4',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.300Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'DEST_GodXP',
#    'teamId': 8,
#    'health': 100,
#    'location': {'x': 789898.8125, 'y': 341136.875, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.28991bc80143444fbc3fe4d53988c0f4',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.312Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.ea7e080d363c4b26850d5e2dfd88c859',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.313Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'SD_Teddy',
#    'teamId': 14,
#    'health': 100,
#    'location': {'x': 789946.5625, 'y': 341726.40625, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.ea7e080d363c4b26850d5e2dfd88c859',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.324Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.be74a810a19a46bda648733595093a32',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.325Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'AOC_Yuri',
#    'teamId': 5,
#    'health': 100,
#    'location': {'x': 587612.1875, 'y': 334177.90625, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.be74a810a19a46bda648733595093a32',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.336Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.aa40ccadf4d14f0fa45ec583ca295c5c',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.337Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'XXX_JHao',
#    'teamId': 16,
#    'health': 100,
#    'location': {'x': 791255.1875, 'y': 340590.5, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.aa40ccadf4d14f0fa45ec583ca295c5c',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.348Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.d0ab1c70b2404462824ea1a905f19601',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.349Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'DBH_BeTa',
#    'teamId': 7,
#    'health': 100,
#    'location': {'x': 587851.9375, 'y': 334548.0625, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.d0ab1c70b2404462824ea1a905f19601',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.360Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.6bc791e69e5a4dd2b86dddcaced72a47',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.361Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'AOC_Homei3',
#    'teamId': 5,
#    'health': 100,
#    'location': {'x': 587012.3125, 'y': 333246.34375, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.6bc791e69e5a4dd2b86dddcaced72a47',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.373Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.51366cf6756f4a249edc1901cb818e7d',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.374Z',
#   '_T': 'LogPlayerLogin'},
#  {'accountId': 'account.8c56038678434903b8f0fc87afceff2e',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.380Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'GST_Yian',
#    'teamId': 10,
#    'health': 100,
#    'location': {'x': 82301.0078125, 'y': 730280.5, 'z': 5170.15234375},
#    'ranking': 0,
#    'accountId': 'account.8c56038678434903b8f0fc87afceff2e',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.391Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.6180a142a171456f95a46e53eb809398',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.392Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'BDM_Shiou',
#    'teamId': 6,
#    'health': 100,
#    'location': {'x': 84425.6484375, 'y': 732300.3125, 'z': 5170.15234375},
#    'ranking': 0,
#    'accountId': 'account.6180a142a171456f95a46e53eb809398',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.403Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.56615bd5372f46c7b0f5a745718c2b75',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.403Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'AIR_ANNIL',
#    'teamId': 2,
#    'health': 100,
#    'location': {'x': 587931.1875, 'y': 334537.28125, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.56615bd5372f46c7b0f5a745718c2b75',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.414Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.fe3f3041590248648eba5cb2d315c8a0',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.415Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'GEX_SSR',
#    'teamId': 9,
#    'health': 100,
#    'location': {'x': 791345.25, 'y': 340637.1875, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.fe3f3041590248648eba5cb2d315c8a0',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.426Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.f0acb6b6350840e890cd9258ce5b33ac',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.427Z',
#   '_T': 'LogPlayerLogin'},
#  {'accountId': 'account.49334dccfbfd432794511d177bd15af1',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.432Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'GST_Jim',
#    'teamId': 10,
#    'health': 100,
#    'location': {'x': 82957.1640625, 'y': 729714.75, 'z': 5170.15234375},
#    'ranking': 0,
#    'accountId': 'account.49334dccfbfd432794511d177bd15af1',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.444Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.1828c189bb7542988cdc4a51fefac358',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.445Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'ACN_lunlun',
#    'teamId': 3,
#    'health': 100,
#    'location': {'x': 587068.4375, 'y': 333965.59375, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.1828c189bb7542988cdc4a51fefac358',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.456Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.b656062909e84843b95607605bc2e7f5',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.457Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'GEX_Savior',
#    'teamId': 9,
#    'health': 100,
#    'location': {'x': 790061.125, 'y': 341213.5625, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.b656062909e84843b95607605bc2e7f5',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.468Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.611063cafcde4a72ac2d2704ad5bd114',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.469Z',
#   '_T': 'LogPlayerLogin'},
#  {'accountId': 'account.43b976c777d24865b1ef0b0a30df42ef',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.475Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'BDM_BuYoLan',
#    'teamId': 6,
#    'health': 100,
#    'location': {'x': 84734.640625, 'y': 732645.25, 'z': 5170.15234375},
#    'ranking': 0,
#    'accountId': 'account.43b976c777d24865b1ef0b0a30df42ef',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.486Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.ef829013e62043e99e2c8af73a94ebd4',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.486Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'TST_Zyan',
#    'teamId': 15,
#    'health': 100,
#    'location': {'x': 790004.875, 'y': 341781.15625, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.ef829013e62043e99e2c8af73a94ebd4',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.498Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.0e0ecb734bfd4a70ba21de861262d01c',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.499Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'XXX_Keres',
#    'teamId': 16,
#    'health': 100,
#    'location': {'x': 790341.8125, 'y': 340953.59375, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.0e0ecb734bfd4a70ba21de861262d01c',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.510Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.f85d47c6bda24146813356b5699d46f7',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.512Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'XXX_Gg',
#    'teamId': 16,
#    'health': 100,
#    'location': {'x': 790166.25, 'y': 341307.90625, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.f85d47c6bda24146813356b5699d46f7',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.523Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.cb49eb5883754a4c89f15cc715a4d1a0',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.524Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'KSR_LuckyJie',
#    'teamId': 12,
#    'health': 100,
#    'location': {'x': 587081, 'y': 334129.6875, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.cb49eb5883754a4c89f15cc715a4d1a0',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.541Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.24dc35a78f064b71944eb8c920f374cb',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.542Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'KB_Ruf',
#    'teamId': 11,
#    'health': 100,
#    'location': {'x': 586772.9375, 'y': 334319.90625, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.24dc35a78f064b71944eb8c920f374cb',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.554Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.ccd25fee99194cd3886dbccdaae03fbe',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.555Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'GST_Andy',
#    'teamId': 10,
#    'health': 100,
#    'location': {'x': 83948.7890625, 'y': 731986.875, 'z': 5170.15234375},
#    'ranking': 0,
#    'accountId': 'account.ccd25fee99194cd3886dbccdaae03fbe',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.566Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.ca0d20c1e058412d9ae64602d702b48b',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.566Z',
#   '_T': 'LogPlayerLogin'},
#  {'accountId': 'account.a95b512743d4443192cfa78968fe131e',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.572Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'KB_KYu18',
#    'teamId': 11,
#    'health': 100,
#    'location': {'x': 586734.8125, 'y': 334154.4375, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.a95b512743d4443192cfa78968fe131e',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.583Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.b0923e48717e428c9196b810a4760e65',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.584Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'AE_UKL',
#    'teamId': 1,
#    'health': 100,
#    'location': {'x': 790985.0625, 'y': 340413.03125, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.b0923e48717e428c9196b810a4760e65',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.595Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.f5986f9ed52e47e0bd5b51ef1b2b8035',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.595Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'RKA_YouZeMoSi',
#    'teamId': 13,
#    'health': 100,
#    'location': {'x': 82978.5703125, 'y': 730674.75, 'z': 5170.15234375},
#    'ranking': 0,
#    'accountId': 'account.f5986f9ed52e47e0bd5b51ef1b2b8035',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.607Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.e71d1677470b4ead8145809c8151a631',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.609Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'ACT_Luda',
#    'teamId': 4,
#    'health': 100,
#    'location': {'x': 84669.0625, 'y': 732761.0625, 'z': 5170.15234375},
#    'ranking': 0,
#    'accountId': 'account.e71d1677470b4ead8145809c8151a631',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.620Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.94686bc7e3514a169f69fdb4d1e4d91e',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.621Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'KB_River',
#    'teamId': 11,
#    'health': 100,
#    'location': {'x': 587193.0625, 'y': 333093.4375, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.94686bc7e3514a169f69fdb4d1e4d91e',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.645Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.ed3a8ee123e944b69876fbea374c5efb',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.646Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'BDM_BuYoHoo',
#    'teamId': 6,
#    'health': 100,
#    'location': {'x': 82052.8828125, 'y': 731671.5, 'z': 5170.15234375},
#    'ranking': 0,
#    'accountId': 'account.ed3a8ee123e944b69876fbea374c5efb',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.658Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.abbf5676b257464daba705854e3f8cb1',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.659Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'DEST_Jagger',
#    'teamId': 8,
#    'health': 100,
#    'location': {'x': 790108.75, 'y': 341450.9375, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.abbf5676b257464daba705854e3f8cb1',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.670Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.35d0c046f99c4bd38ad446d1628b8046',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.671Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'SD_Sophiya',
#    'teamId': 14,
#    'health': 100,
#    'location': {'x': 791059.5, 'y': 340622.96875, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.35d0c046f99c4bd38ad446d1628b8046',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.682Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.2effee93f0db41c8811ebfeec8fd6af5',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.685Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'ACN_xxxliu',
#    'teamId': 3,
#    'health': 100,
#    'location': {'x': 586950.25, 'y': 334226.40625, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.2effee93f0db41c8811ebfeec8fd6af5',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.696Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.86d24bbc59d5471e91a22a90ec4c5771',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.698Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'DBH_AJun',
#    'teamId': 7,
#    'health': 100,
#    'location': {'x': 588216.5, 'y': 334304.25, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.86d24bbc59d5471e91a22a90ec4c5771',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.709Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.bac702206aa844d995623580fc400a38',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.710Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'RKA_YouZeMoPi',
#    'teamId': 13,
#    'health': 100,
#    'location': {'x': 83252.640625, 'y': 732866.6875, 'z': 5170.15234375},
#    'ranking': 0,
#    'accountId': 'account.bac702206aa844d995623580fc400a38',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.721Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.05acaad24a0345549894b8e6ab4bff2f',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.723Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'TST_Mizty',
#    'teamId': 15,
#    'health': 100,
#    'location': {'x': 790927.75, 'y': 342025.1875, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.05acaad24a0345549894b8e6ab4bff2f',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.734Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.b7dee7ccd0bd48058e05b326f2e5aa0b',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.736Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'AE_CrazyDog',
#    'teamId': 1,
#    'health': 100,
#    'location': {'x': 790169.0625, 'y': 340555.875, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.b7dee7ccd0bd48058e05b326f2e5aa0b',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.747Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.95fc439e82564b769aa88d07611455b2',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.747Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'GEX_ZhenNan',
#    'teamId': 9,
#    'health': 100,
#    'location': {'x': 790055.3125, 'y': 341934.75, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.95fc439e82564b769aa88d07611455b2',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.758Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.b694743bdeef4617bd9cd173eb7cdc51',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.759Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'DBH_BiJie',
#    'teamId': 7,
#    'health': 100,
#    'location': {'x': 586934.0625, 'y': 333318.8125, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.b694743bdeef4617bd9cd173eb7cdc51',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.771Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.7dec0e280f0f4cf987ae55d898339d52',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.773Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'GEX_YanLi',
#    'teamId': 9,
#    'health': 100,
#    'location': {'x': 790158.4375, 'y': 340772.40625, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.7dec0e280f0f4cf987ae55d898339d52',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.784Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.42211b94f6be42a1b9eb0b74a4ccdfa1',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.785Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'GST_Xiaoyu',
#    'teamId': 10,
#    'health': 100,
#    'location': {'x': 82910.7421875, 'y': 729785.125, 'z': 5170.15234375},
#    'ranking': 0,
#    'accountId': 'account.42211b94f6be42a1b9eb0b74a4ccdfa1',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.797Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.8051f91837764edc9825541f98fc2119',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.798Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'RKA_YouZeMoLa',
#    'teamId': 13,
#    'health': 100,
#    'location': {'x': 82455.4453125, 'y': 729694.375, 'z': 5170.15234375},
#    'ranking': 0,
#    'accountId': 'account.8051f91837764edc9825541f98fc2119',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.810Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.65e48c0fa8e246fc80c7d1b58fc46311',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.812Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'SD_Upchen',
#    'teamId': 14,
#    'health': 100,
#    'location': {'x': 791462.5625, 'y': 341227.34375, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.65e48c0fa8e246fc80c7d1b58fc46311',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.823Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.6ec27e50f4264bd19f54bfdb6a8f4d2d',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.826Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'TST_Faith',
#    'teamId': 15,
#    'health': 100,
#    'location': {'x': 790484.625, 'y': 341265.4375, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.6ec27e50f4264bd19f54bfdb6a8f4d2d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.837Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.0a65f26676e04aab83a945b3f719f53d',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.838Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'AIR_XiaoBai',
#    'teamId': 2,
#    'health': 100,
#    'location': {'x': 587177.4375, 'y': 334621.21875, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.0a65f26676e04aab83a945b3f719f53d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.856Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.fdbc65a04c6544e1b32c180be8812b81',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.858Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'ACT_GuoHong',
#    'teamId': 4,
#    'health': 100,
#    'location': {'x': 83718.078125, 'y': 729632, 'z': 5170.15234375},
#    'ranking': 0,
#    'accountId': 'account.fdbc65a04c6544e1b32c180be8812b81',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.869Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.3bc78c44e8b14464b12bf9cb25490c4d',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.871Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'KB_Kor',
#    'teamId': 11,
#    'health': 100,
#    'location': {'x': 587740, 'y': 333289.28125, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.3bc78c44e8b14464b12bf9cb25490c4d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.882Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.5c42fa9540784e0eabebdf257630e4fb',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.885Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'AE_9ineTwo1ne',
#    'teamId': 1,
#    'health': 100,
#    'location': {'x': 790645.125, 'y': 340270.4375, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.5c42fa9540784e0eabebdf257630e4fb',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.897Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.8e1bc205875d4067ac2ed03339f7d907',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.898Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'AOC_McCrit',
#    'teamId': 5,
#    'health': 100,
#    'location': {'x': 587638.4375, 'y': 334454.53125, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.8e1bc205875d4067ac2ed03339f7d907',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.916Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.fe5fd996de474015a5b46db81aff6849',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.917Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'ACN_YaFAn',
#    'teamId': 3,
#    'health': 100,
#    'location': {'x': 587510.5625, 'y': 333323.75, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.fe5fd996de474015a5b46db81aff6849',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.929Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.881404cf73a74f469c508160214f7dce',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.930Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'DBH_HebeDD',
#    'teamId': 7,
#    'health': 100,
#    'location': {'x': 587656.5, 'y': 332832.4375, 'z': 10717.2138671875},
#    'ranking': 0,
#    'accountId': 'account.881404cf73a74f469c508160214f7dce',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.941Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.079cdb2fdb7a4664a338c42c1574e6e9',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.942Z',
#   '_T': 'LogPlayerLogin'},
#  {'accountId': 'account.fcf6ef55bf1247e29ce411872382f6f0',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.950Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'XXX_NiGo',
#    'teamId': 16,
#    'health': 100,
#    'location': {'x': 790863.25, 'y': 342072.53125, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.fcf6ef55bf1247e29ce411872382f6f0',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.962Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.b9f7f1edc0714ed9bfdc397f803eb26a',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.966Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'SD_Shen',
#    'teamId': 14,
#    'health': 100,
#    'location': {'x': 790561.625, 'y': 341091.6875, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.b9f7f1edc0714ed9bfdc397f803eb26a',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.977Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.a4a4da94f3d94ef9a39176e536af8529',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.978Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'KSR_Light',
#    'teamId': 12,
#    'health': 100,
#    'location': {'x': 587020.5, 'y': 333637.375, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.a4a4da94f3d94ef9a39176e536af8529',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.990Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.33ae944183974415b2c1481fe83be0a2',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.991Z',
#   '_T': 'LogPlayerLogin'},
#  {'accountId': 'account.fc20cde23b41463dae909bc52b1c24f5',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:23.999Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'TST_Chenghan',
#    'teamId': 15,
#    'health': 100,
#    'location': {'x': 789877.6875, 'y': 341364, 'z': 121.66309356689453},
#    'ranking': 0,
#    'accountId': 'account.fc20cde23b41463dae909bc52b1c24f5',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:24.010Z',
#   '_T': 'LogPlayerCreate'},
#  {'character': {'name': 'AOC_Yuri',
#    'teamId': 5,
#    'health': 100,
#    'location': {'x': 587612.1875, 'y': 334177.90625, 'z': 10696.228515625},
#    'ranking': 0,
#    'accountId': 'account.be74a810a19a46bda648733595093a32',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 60,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:24.038Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'GST_Yian',
#    'teamId': 10,
#    'health': 100,
#    'location': {'x': 82301.0078125, 'y': 730280.5, 'z': 5170.15234375},
#    'ranking': 0,
#    'accountId': 'account.8c56038678434903b8f0fc87afceff2e',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 60,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:24.038Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'AOC_Homei3',
#    'teamId': 5,
#    'health': 100,
#    'location': {'x': 587012.3125, 'y': 333246.34375, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.6bc791e69e5a4dd2b86dddcaced72a47',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 60,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:24.038Z',
#   '_T': 'LogPlayerPosition'},
#  {'accountId': 'account.beb43dae6c06464fa28d565a2413cd82',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:24.052Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'ACT_ind1ngu',
#    'teamId': 4,
#    'health': 100,
#    'location': {'x': 83012.1953125, 'y': 729776.8125, 'z': 5170.15234375},
#    'ranking': 0,
#    'accountId': 'account.beb43dae6c06464fa28d565a2413cd82',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:24.064Z',
#   '_T': 'LogPlayerCreate'},
#  {'character': {'name': 'ACN_xxxliu',
#    'teamId': 3,
#    'health': 100,
#    'location': {'x': 586950.25, 'y': 334226.40625, 'z': 10572.1025390625},
#    'ranking': 0,
#    'accountId': 'account.2effee93f0db41c8811ebfeec8fd6af5',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 61,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:24.765Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'RKA_YouZeMoLa',
#    'teamId': 13,
#    'health': 100,
#    'location': {'x': 82455.4453125, 'y': 729694.375, 'z': 5108.150390625},
#    'ranking': 0,
#    'accountId': 'account.8051f91837764edc9825541f98fc2119',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 61,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:24.765Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'GST_Xiaoyu',
#    'teamId': 10,
#    'health': 100,
#    'location': {'x': 82910.7421875, 'y': 729785.125, 'z': 5108.150390625},
#    'ranking': 0,
#    'accountId': 'account.42211b94f6be42a1b9eb0b74a4ccdfa1',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 61,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:24.765Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'AE_UKL',
#    'teamId': 1,
#    'health': 100,
#    'location': {'x': 790985.0625, 'y': 340413.03125, 'z': 119.05284881591797},
#    'ranking': 0,
#    'accountId': 'account.b0923e48717e428c9196b810a4760e65',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 61,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:24.801Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'TST_Zyan',
#    'teamId': 15,
#    'health': 100,
#    'location': {'x': 790005, 'y': 341781.25, 'z': 119.8367691040039},
#    'ranking': 0,
#    'accountId': 'account.ef829013e62043e99e2c8af73a94ebd4',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 61,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:24.802Z',
#   '_T': 'LogPlayerPosition'},
#  {'accountId': 'account.3567c039b789484e8414de168dcacfff',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:24.887Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'BDM_Life',
#    'teamId': 6,
#    'health': 100,
#    'location': {'x': 81790.2734375, 'y': 731729.875, 'z': 5170.15234375},
#    'ranking': 0,
#    'accountId': 'account.3567c039b789484e8414de168dcacfff',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:24.899Z',
#   '_T': 'LogPlayerCreate'},
#  {'character': {'name': 'AOC_oeL',
#    'teamId': 5,
#    'health': 100,
#    'location': {'x': 587846.875, 'y': 332895.125, 'z': 10688.8232421875},
#    'ranking': 0,
#    'accountId': 'account.27b7ad383e454c80becf03dcd5b0fe7c',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 62,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:24.910Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'ACN_OkYouDiE',
#    'teamId': 3,
#    'health': 100,
#    'location': {'x': 587121.6875, 'y': 333905.875, 'z': 10571.845703125},
#    'ranking': 0,
#    'accountId': 'account.2dc85ea2f3e6423f9b2fcdedd0843557',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 62,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:24.943Z',
#   '_T': 'LogPlayerPosition'},
#  {'accountId': 'account.a0fc633340d44a81b6829de2f37f37ca',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:24.958Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'AIR_RaNDLLL',
#    'teamId': 2,
#    'health': 100,
#    'location': {'x': 586652.25, 'y': 333214.625, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.a0fc633340d44a81b6829de2f37f37ca',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:24.970Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.45da9f24ff654136b104e5b28cb3ff90',
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:24.978Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'AIR_itsLouis',
#    'teamId': 2,
#    'health': 100,
#    'location': {'x': 587903.5625, 'y': 334029.59375, 'z': 10712.7119140625},
#    'ranking': 0,
#    'accountId': 'account.45da9f24ff654136b104e5b28cb3ff90',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:24.990Z',
#   '_T': 'LogPlayerCreate'},
#  {'character': {'name': 'ACN_lunlun',
#    'teamId': 3,
#    'health': 100,
#    'location': {'x': 587068.4375, 'y': 333965.59375, 'z': 10572.01953125},
#    'ranking': 0,
#    'accountId': 'account.1828c189bb7542988cdc4a51fefac358',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 64,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:25.484Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'BDM_BuYoHoo',
#    'teamId': 6,
#    'health': 100,
#    'location': {'x': 82052.8828125, 'y': 731671.5, 'z': 5104.212890625},
#    'ranking': 0,
#    'accountId': 'account.ed3a8ee123e944b69876fbea374c5efb',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 64,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:25.800Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'AOC_McCrit',
#    'teamId': 5,
#    'health': 100,
#    'location': {'x': 587638.4375, 'y': 334454.53125, 'z': 10595.1953125},
#    'ranking': 0,
#    'accountId': 'account.8e1bc205875d4067ac2ed03339f7d907',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 64,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:25.936Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'RKA_YouZeMoLe',
#    'teamId': 13,
#    'health': 100,
#    'location': {'x': 82548.6796875, 'y': 732568.625, 'z': 5104.212890625},
#    'ranking': 0,
#    'accountId': 'account.aa5076cf4b6e41f0b3047539eca098dc',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 64,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:26.086Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'RKA_YouZeMoSi',
#    'teamId': 13,
#    'health': 100,
#    'location': {'x': 82978.5703125, 'y': 730674.75, 'z': 5104.21142578125},
#    'ranking': 0,
#    'accountId': 'account.f5986f9ed52e47e0bd5b51ef1b2b8035',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 64,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:26.559Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'ACT_GuoHong',
#    'teamId': 4,
#    'health': 100,
#    'location': {'x': 83718.078125, 'y': 729632, 'z': 5108.150390625},
#    'ranking': 0,
#    'accountId': 'account.fdbc65a04c6544e1b32c180be8812b81',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 64,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:26.723Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'SD_Sophiya',
#    'teamId': 14,
#    'health': 100,
#    'location': {'x': 791059.5, 'y': 340622.96875, 'z': 119.05624389648438},
#    'ranking': 0,
#    'accountId': 'account.35d0c046f99c4bd38ad446d1628b8046',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 64,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:26.962Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'SD_Teddy',
#    'teamId': 14,
#    'health': 100,
#    'location': {'x': 789946.5625, 'y': 341726.40625, 'z': 119.8346176147461},
#    'ranking': 0,
#    'accountId': 'account.ea7e080d363c4b26850d5e2dfd88c859',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 64,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:26.962Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'DBH_HebeDD',
#    'teamId': 7,
#    'health': 100,
#    'location': {'x': 587656.5, 'y': 332832.4375, 'z': 10719.3896484375},
#    'ranking': 0,
#    'accountId': 'account.881404cf73a74f469c508160214f7dce',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 64,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:27.327Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'AIR_ANNIL',
#    'teamId': 2,
#    'health': 100,
#    'location': {'x': 587931.1875, 'y': 334537.28125, 'z': 10569.9248046875},
#    'ranking': 0,
#    'accountId': 'account.56615bd5372f46c7b0f5a745718c2b75',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 64,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:27.721Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'AE_9ineTwo1ne',
#    'teamId': 1,
#    'health': 100,
#    'location': {'x': 790645.125, 'y': 340270.4375, 'z': 119.05233764648438},
#    'ranking': 0,
#    'accountId': 'account.5c42fa9540784e0eabebdf257630e4fb',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 64,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:28.262Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'KSR_LzHan',
#    'teamId': 12,
#    'health': 100,
#    'location': {'x': 586687.1875, 'y': 334314.59375, 'z': 10567.0390625},
#    'ranking': 0,
#    'accountId': 'account.e95604a805244c69a330bfaea6182ede',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 64,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:28.380Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'GST_Jim',
#    'teamId': 10,
#    'health': 100,
#    'location': {'x': 82957.1640625, 'y': 729714.75, 'z': 5108.150390625},
#    'ranking': 0,
#    'accountId': 'account.49334dccfbfd432794511d177bd15af1',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 64,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:28.449Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'BDM_BuYoLan',
#    'teamId': 6,
#    'health': 100,
#    'location': {'x': 84734.640625, 'y': 732645.25, 'z': 5104.212890625},
#    'ranking': 0,
#    'accountId': 'account.43b976c777d24865b1ef0b0a30df42ef',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 64,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:28.574Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'DBH_BiJie',
#    'teamId': 7,
#    'health': 100,
#    'location': {'x': 586934.0625, 'y': 333318.8125, 'z': 10571.216796875},
#    'ranking': 0,
#    'accountId': 'account.b694743bdeef4617bd9cd173eb7cdc51',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 64,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:28.662Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'RKA_YouZeMoPi',
#    'teamId': 13,
#    'health': 100,
#    'location': {'x': 83252.640625, 'y': 732866.6875, 'z': 5104.2138671875},
#    'ranking': 0,
#    'accountId': 'account.bac702206aa844d995623580fc400a38',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 64,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:28.662Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'KSR_Light',
#    'teamId': 12,
#    'health': 100,
#    'location': {'x': 587020.5, 'y': 333637.375, 'z': 10564.4248046875},
#    'ranking': 0,
#    'accountId': 'account.a4a4da94f3d94ef9a39176e536af8529',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 64,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:28.829Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'AIR_XiaoBai',
#    'teamId': 2,
#    'health': 100,
#    'location': {'x': 587177.4375, 'y': 334621.21875, 'z': 10631.8623046875},
#    'ranking': 0,
#    'accountId': 'account.0a65f26676e04aab83a945b3f719f53d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 64,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:13:28.864Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'XXX_Keres',
# ...
#    'ranking': 0,
#    'accountId': 'account.24dc35a78f064b71944eb8c920f374cb',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:30.207Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'XXX_NiGo',
#    'teamId': 16,
#    'health': 100,
#    'location': {'x': 790863.25, 'y': 342072.46875, 'z': 119.80000305175781},
#    'ranking': 0,
#    'accountId': 'account.fcf6ef55bf1247e29ce411872382f6f0',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:30.324Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'DEST_Jagger',
#    'teamId': 8,
#    'health': 100,
#    'location': {'x': 790108.8125, 'y': 341451, 'z': 119.80000305175781},
#    'ranking': 0,
#    'accountId': 'account.abbf5676b257464daba705854e3f8cb1',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:30.425Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'KSR_P0rr1dge',
#    'teamId': 12,
#    'health': 100,
#    'location': {'x': 590915.1875, 'y': 334997.5625, 'z': 10501.400390625},
#    'ranking': 0,
#    'accountId': 'account.a5357a4b2c0f46228cb601fc11e2a9c2',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:30.508Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'DBH_AJun',
#    'teamId': 7,
#    'health': 100,
#    'location': {'x': 589816.375, 'y': 336635.71875, 'z': 10656.0498046875},
#    'ranking': 0,
#    'accountId': 'account.86d24bbc59d5471e91a22a90ec4c5771',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:30.726Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'KB_River',
#    'teamId': 11,
#    'health': 100,
#    'location': {'x': 587193.0625, 'y': 333093.4375, 'z': 10559.240234375},
#    'ranking': 0,
#    'accountId': 'account.94686bc7e3514a169f69fdb4d1e4d91e',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:30.810Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'GEX_YanLi',
#    'teamId': 9,
#    'health': 100,
#    'location': {'x': 789834.9375, 'y': 338479.5625, 'z': 119.83999633789062},
#    'ranking': 0,
#    'accountId': 'account.7dec0e280f0f4cf987ae55d898339d52',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:30.843Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'XXX_Gg',
#    'teamId': 16,
#    'health': 100,
#    'location': {'x': 790166.3125, 'y': 341307.90625, 'z': 119.80000305175781},
#    'ranking': 0,
#    'accountId': 'account.f85d47c6bda24146813356b5699d46f7',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:31.378Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'AIR_RaNDLLL',
#    'teamId': 2,
#    'health': 100,
#    'location': {'x': 585934.1875, 'y': 334761.21875, 'z': 10756.7802734375},
#    'ranking': 0,
#    'accountId': 'account.a0fc633340d44a81b6829de2f37f37ca',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:31.679Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'DEST_GodXP',
#    'teamId': 8,
#    'health': 100,
#    'location': {'x': 790200.875, 'y': 341130.71875, 'z': 119.80000305175781},
#    'ranking': 0,
#    'accountId': 'account.28991bc80143444fbc3fe4d53988c0f4',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:31.763Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'AIR_itsLouis',
#    'teamId': 2,
#    'health': 100,
#    'location': {'x': 587903.5625, 'y': 334029.59375, 'z': 10600.509765625},
#    'ranking': 0,
#    'accountId': 'account.45da9f24ff654136b104e5b28cb3ff90',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:31.880Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'ACT_Luda',
#    'teamId': 4,
#    'health': 100,
#    'location': {'x': 81629.3515625, 'y': 735357.75, 'z': 5395.08984375},
#    'ranking': 0,
#    'accountId': 'account.e71d1677470b4ead8145809c8151a631',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:32.064Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'GEX_Savior',
#    'teamId': 9,
#    'health': 100,
#    'location': {'x': 789328.375, 'y': 341940.59375, 'z': 119.83999633789062},
#    'ranking': 0,
#    'accountId': 'account.b656062909e84843b95607605bc2e7f5',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:32.164Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'GEX_SSR',
#    'teamId': 9,
#    'health': 100,
#    'location': {'x': 772792.1875, 'y': 309235.25, 'z': 252.5500030517578},
#    'ranking': 0,
#    'accountId': 'account.fe3f3041590248648eba5cb2d315c8a0',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:32.265Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'DEST_ChunQ1ng',
#    'teamId': 8,
#    'health': 100,
#    'location': {'x': 790805.25, 'y': 341487.40625, 'z': 119.80000305175781},
#    'ranking': 0,
#    'accountId': 'account.a019bcd905ca428c9472fef49c63269d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:32.449Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'TST_Mizty',
#    'teamId': 15,
#    'health': 100,
#    'location': {'x': 790732.375, 'y': 341964.46875, 'z': 119.80000305175781},
#    'ranking': 0,
#    'accountId': 'account.05acaad24a0345549894b8e6ab4bff2f',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:32.515Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'GEX_ZhenNan',
#    'teamId': 9,
#    'health': 100,
#    'location': {'x': 764631.5, 'y': 321690.25, 'z': -79.94999694824219},
#    'ranking': 0,
#    'accountId': 'account.95fc439e82564b769aa88d07611455b2',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:32.733Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'KB_Kor',
#    'teamId': 11,
#    'health': 100,
#    'location': {'x': 587740, 'y': 333289.28125, 'z': 10598},
#    'ranking': 0,
#    'accountId': 'account.3bc78c44e8b14464b12bf9cb25490c4d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:32.884Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'ACT_MaoMao',
#    'teamId': 4,
#    'health': 100,
#    'location': {'x': 83233.7109375, 'y': 730207.8125, 'z': 5080.14990234375},
#    'ranking': 0,
#    'accountId': 'account.2af5557929de48afa7fe370996b0cbe5',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:32.950Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'BDM_Shiou',
#    'teamId': 6,
#    'health': 100,
#    'location': {'x': 81397.9375, 'y': 734523.625, 'z': 5399.5400390625},
#    'ranking': 0,
#    'accountId': 'account.6180a142a171456f95a46e53eb809398',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:32.984Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'ACN_YaFAn',
#    'teamId': 3,
#    'health': 100,
#    'location': {'x': 587510.5625, 'y': 333323.75, 'z': 10556.58984375},
#    'ranking': 0,
#    'accountId': 'account.fe5fd996de474015a5b46db81aff6849',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:33.201Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'SD_Shen',
#    'teamId': 14,
#    'health': 100,
#    'location': {'x': 790561.625, 'y': 341091.71875, 'z': 119.80000305175781},
#    'ranking': 0,
#    'accountId': 'account.b9f7f1edc0714ed9bfdc397f803eb26a',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:33.302Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'ACT_ind1ngu',
#    'teamId': 4,
#    'health': 100,
#    'location': {'x': 37008.3203125, 'y': 737888.375, 'z': -1797.8299560546875},
#    'ranking': 0,
#    'accountId': 'account.beb43dae6c06464fa28d565a2413cd82',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:33.335Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'TST_Faith',
#    'teamId': 15,
#    'health': 100,
#    'location': {'x': 790484.625, 'y': 341265.53125, 'z': 119.80000305175781},
#    'ranking': 0,
#    'accountId': 'account.6ec27e50f4264bd19f54bfdb6a8f4d2d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:33.536Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'SD_Upchen',
#    'teamId': 14,
#    'health': 100,
#    'location': {'x': 791462.625, 'y': 341227.40625, 'z': 119.80000305175781},
#    'ranking': 0,
#    'accountId': 'account.65e48c0fa8e246fc80c7d1b58fc46311',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:33.620Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'GST_Andy',
#    'teamId': 10,
#    'health': 100,
#    'location': {'x': 85932.828125, 'y': 724555.125, 'z': 5327.169921875},
#    'ranking': 0,
#    'accountId': 'account.ccd25fee99194cd3886dbccdaae03fbe',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:33.720Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'XXX_JHao',
#    'teamId': 16,
#    'health': 100,
#    'location': {'x': 791255.1875, 'y': 340590.46875, 'z': 119.19999694824219},
#    'ranking': 0,
#    'accountId': 'account.aa40ccadf4d14f0fa45ec583ca295c5c',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:33.720Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'KB_KYu18',
#    'teamId': 11,
#    'health': 100,
#    'location': {'x': 586734.8125, 'y': 334154.4375, 'z': 10565.150390625},
#    'ranking': 0,
#    'accountId': 'account.a95b512743d4443192cfa78968fe131e',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:33.820Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'AOC_Yuri',
#    'teamId': 5,
#    'health': 100,
#    'location': {'x': 587612.1875, 'y': 334177.90625, 'z': 10696.2001953125},
#    'ranking': 0,
#    'accountId': 'account.be74a810a19a46bda648733595093a32',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:34.071Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'GST_Yian',
#    'teamId': 10,
#    'health': 100,
#    'location': {'x': 67425.6796875, 'y': 723801.625, 'z': 4985.83984375},
#    'ranking': 0,
#    'accountId': 'account.8c56038678434903b8f0fc87afceff2e',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:34.188Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'AOC_Homei3',
#    'teamId': 5,
#    'health': 100,
#    'location': {'x': 587009.0625, 'y': 333247.875, 'z': 10561.8603515625},
#    'ranking': 0,
#    'accountId': 'account.6bc791e69e5a4dd2b86dddcaced72a47',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:34.189Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'BDM_Life',
#    'teamId': 6,
#    'health': 100,
#    'location': {'x': 83463.4375, 'y': 735719.5, 'z': 5104.22021484375},
#    'ranking': 0,
#    'accountId': 'account.3567c039b789484e8414de168dcacfff',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:34.239Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'ACN_xxxliu',
#    'teamId': 3,
#    'health': 100,
#    'location': {'x': 586658.125, 'y': 335648.28125, 'z': 10785.1396484375},
#    'ranking': 0,
#    'accountId': 'account.2effee93f0db41c8811ebfeec8fd6af5',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:34.356Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'RKA_YouZeMoLa',
#    'teamId': 13,
#    'health': 100,
#    'location': {'x': 83185.6484375, 'y': 698550.5625, 'z': 6429.1298828125},
#    'ranking': 0,
#    'accountId': 'account.8051f91837764edc9825541f98fc2119',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:34.406Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'GST_Xiaoyu',
#    'teamId': 10,
#    'health': 100,
#    'location': {'x': 87321.171875, 'y': 723107.0625, 'z': 5139.490234375},
#    'ranking': 0,
#    'accountId': 'account.42211b94f6be42a1b9eb0b74a4ccdfa1',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:34.523Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'AE_UKL',
#    'teamId': 1,
#    'health': 100,
#    'location': {'x': 790985.125, 'y': 340413, 'z': 119.0999984741211},
#    'ranking': 0,
#    'accountId': 'account.b0923e48717e428c9196b810a4760e65',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 63,
#   'common': {'isGame': 0},
#   '_D': '2022-03-24T11:15:34.707Z',
#   '_T': 'LogPlayerPosition'},
#  ...]

# %%
K = []

# %%
[K.append(x['dBNODamageInfo']['damageCauserName']) for x in telemetryData if(x['_T'] == 'LogPlayerKillV2')]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
K
# Out:
# ['WeapWinchester_C',
#  'PlayerMale_A_C',
#  'WeapBerylM762_C',
#  'WeapSKS_C',
#  'WeapBerylM762_C',
#  'PlayerMale_A_C',
#  'WeapHK416_C',
#  'WeapKar98k_C',
#  'PlayerFemale_A_C',
#  'WeapBerylM762_C',
#  'WeapBerylM762_C',
#  'PlayerFemale_A_C',
#  'PlayerFemale_A_C',
#  'PlayerFemale_A_C',
#  'WeapBerylM762_C',
#  'WeapMini14_C',
#  'PlayerFemale_A_C',
#  'ProjGrenade_C',
#  'PlayerFemale_A_C',
#  'PlayerFemale_A_C',
#  'WeapFNFal_C',
#  'PlayerFemale_A_C',
#  'PlayerFemale_A_C',
#  'PlayerFemale_A_C',
#  'WeapBerylM762_C',
#  'WeapHK416_C',
#  'PlayerFemale_A_C',
#  'PlayerFemale_A_C',
#  'PlayerFemale_A_C',
#  'WeapBerylM762_C',
#  'PlayerFemale_A_C',
#  'PlayerFemale_A_C',
#  'WeapHK416_C',
#  'PlayerMale_A_C',
#  'PlayerMale_A_C',
#  'WeapBerylM762_C',
#  'WeapBerylM762_C',
#  'WeapBerylM762_C',
#  'WeapMini14_C',
#  'WeapBerylM762_C',
#  'WeapFNFal_C',
#  'PlayerFemale_A_C',
#  'PlayerFemale_A_C',
#  'WeapHK416_C',
#  'WeapFNFal_C',
#  'WeapBerylM762_C',
#  'WeapHK416_C',
#  'PlayerFemale_A_C',
#  'WeapHK416_C',
#  'PlayerFemale_A_C',
#  'WeapBerylM762_C',
#  'PlayerFemale_A_C',
#  'WeapBerylM762_C',
#  'WeapFNFal_C',
#  'WeapHK416_C',
#  'BattleRoyaleModeController_Desert_C',
#  'WeapHK416_C',
#  'PlayerFemale_A_C',
#  'PlayerFemale_A_C',
#  'WeapHK416_C']

# %%
len(K)
# Out:
# 60

# %%
K
# Out:
# ['WeapWinchester_C',
#  'WeapMini14_C',
#  'ProjGrenade_C',
#  'WeapBerylM762_C',
#  'WeapBerylM762_C',
#  'WeapAK47_C',
#  'None',
#  'WeapHK416_C',
#  'WeapBerylM762_C',
#  'None',
#  'WeapBerylM762_C',
#  'WeapHK416_C',
#  'WeapHK416_C',
#  'WeapHK416_C',
#  'None',
#  'WeapHK416_C',
#  'WeapBerylM762_C',
#  'None',
#  'WeapFNFal_C',
#  'WeapFNFal_C',
#  'WeapFNFal_C',
#  'WeapBerylM762_C',
#  'WeapMini14_C',
#  'WeapMini14_C',
#  'None',
#  'WeapHK416_C',
#  'WeapBerylM762_C',
#  'WeapBerylM762_C',
#  'WeapBerylM762_C',
#  'None',
#  'WeapHK416_C',
#  'WeapHK416_C',
#  'None',
#  'WeapBerylM762_C',
#  'WeapHK416_C',
#  'None',
#  'WeapBerylM762_C',
#  'WeapBerylM762_C',
#  'ProjGrenade_C',
#  'None',
#  'WeapMini14_C',
#  'WeapHK416_C',
#  'WeapHK416_C',
#  'None',
#  'WeapFNFal_C',
#  'WeapBerylM762_C',
#  'WeapMini14_C',
#  'WeapMini14_C',
#  'None',
#  'WeapBerylM762_C',
#  'WeapBerylM762_C',
#  'WeapHK416_C',
#  'None',
#  'WeapBerylM762_C',
#  'ProjGrenade_C',
#  'None',
#  'None',
#  'WeapBerylM762_C',
#  'WeapBerylM762_C',
#  'None']
